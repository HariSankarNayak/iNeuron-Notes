# %%
import pandas as pd

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
df=pd.read_json(url)

# %%
import requests
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
df=data.json()

# %%
df
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46210',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46210/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46210/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46210/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46210',
#   'id': 1158374398,
#   'node_id': 'I_kwDOAA0YD85FC2P-',
#   'number': 46210,
#   'title': 'BUG: UserWarning about lacking infer_datetime_format with pd.to_datetime',
#   'user': {'login': 'moojen',
#    'id': 18547401,
#    'node_id': 'MDQ6VXNlcjE4NTQ3NDAx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18547401?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/moojen',
#    'html_url': 'https://github.com/moojen',
#    'followers_url': 'https://api.github.com/users/moojen/followers',
#    'following_url': 'https://api.github.com/users/moojen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/moojen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/moojen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/moojen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/moojen/orgs',
#    'repos_url': 'https://api.github.com/users/moojen/repos',
#    'events_url': 'https://api.github.com/users/moojen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/moojen/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-03T12:53:26Z',
#   'updated_at': '2022-03-03T12:55:02Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\ndf[\'date\'] = pd.to_datetime(df[\'date\'], infer_datetime_format=True, utc=True, errors=\'ignore\')\n```\n\n\n### Issue Description\n\nWhen I run this code, I get the following warning:\r\n\r\n"UserWarning: Parsing \'15/09/1979\' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing."\r\n\r\nWhich is strange, because I already have set infer_datetime_format=True. \n\n### Expected Behavior\n\nYou would expect no warning at all, since "infer_datetime_format=True" is already provided as an argument.\n\n### Installed Versions\n\n<details>\r\npymysql : None\r\nhtml5lib : None\r\nlxml.etree : 4.8.0\r\nxlsxwriter : None\r\nfeather : None\r\nblosc : None\r\nsphinx : None\r\nhypothesis : None\r\npytest : 6.2.5\r\nCython : None\r\nsetuptools : 58.1.0\r\npip : 22.0.3\r\ndateutil : 2.8.2\r\npytz : 2021.3\r\nnumpy : 1.22.2\r\npandas : 1.4.1\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46210/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46210/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46209',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46209/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46209/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46209/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46209',
#   'id': 1157875795,
#   'node_id': 'PR_kwDOAA0YD84z3TEH',
#   'number': 46209,
#   'title': 'BUG: Fix some cases of groupby(...).transform with dropna=True',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-03T01:48:05Z',
#   'updated_at': '2022-03-03T01:51:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46209',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46209',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46209.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46209.patch',
#    'merged_at': None},
#   'body': 'Part of #17093\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThe added xfails will pass when other parts of #45839 are merged.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46209/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46209/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46208',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46208/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46208/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46208/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46208',
#   'id': 1157835973,
#   'node_id': 'PR_kwDOAA0YD84z3LD4',
#   'number': 46208,
#   'title': 'PERF: avoid object dtype cast for Categorical in _ensure_data',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-03T00:31:41Z',
#   'updated_at': '2022-03-03T00:31:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46208',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46208',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46208.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46208.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46208/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46208/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46207',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46207/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46207/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46207/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46207',
#   'id': 1157819010,
#   'node_id': 'PR_kwDOAA0YD84z3HeN',
#   'number': 46207,
#   'title': 'REF: Move Categorical logic from Grouping (#46203)',
#   'user': {'login': 'NickCrews',
#    'id': 10820686,
#    'node_id': 'MDQ6VXNlcjEwODIwNjg2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10820686?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NickCrews',
#    'html_url': 'https://github.com/NickCrews',
#    'followers_url': 'https://api.github.com/users/NickCrews/followers',
#    'following_url': 'https://api.github.com/users/NickCrews/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NickCrews/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NickCrews/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NickCrews/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NickCrews/orgs',
#    'repos_url': 'https://api.github.com/users/NickCrews/repos',
#    'events_url': 'https://api.github.com/users/NickCrews/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/NickCrews/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-03T00:04:28Z',
#   'updated_at': '2022-03-03T15:02:03Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46207',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46207',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46207.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46207.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46203 (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46207/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46207/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46205',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46205/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46205/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46205/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46205',
#   'id': 1157652834,
#   'node_id': 'I_kwDOAA0YD85FAGFi',
#   'number': 46205,
#   'title': 'DOC: provide detailed information about building the C extensions (development environment)',
#   'user': {'login': 'rendner',
#    'id': 414652,
#    'node_id': 'MDQ6VXNlcjQxNDY1Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/414652?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rendner',
#    'html_url': 'https://github.com/rendner',
#    'followers_url': 'https://api.github.com/users/rendner/followers',
#    'following_url': 'https://api.github.com/users/rendner/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rendner/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rendner/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rendner/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rendner/orgs',
#    'repos_url': 'https://api.github.com/users/rendner/repos',
#    'events_url': 'https://api.github.com/users/rendner/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rendner/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-02T20:22:15Z',
#   'updated_at': '2022-03-02T20:22:15Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/development/contributing_environment.html#creating-a-development-environment\n\n### Documentation problem\n\nTo setup a local development environment the user has to build the C extensions.\r\nThe current description contains minimal information about how to build the C extensions.\r\n\r\nThe information has already been expanded somewhat in PR #46055, but it would be helpful to provide more detailed information.\n\n### Suggested fix for documentation\n\nExtract the already existing information into a separate section.\r\nIn addition, the new section should provide the user with more detailed information on the following questions:\r\n\r\n- Why do these need to be build?\r\n- How to build?\r\n- When do they need to be build or rebuild? \r\n\r\nThe existing sections [Creating an environment using Docker](https://pandas.pydata.org/docs/development/contributing_environment.html#creating-an-environment-using-docker) and [Creating an environment without Docker](https://pandas.pydata.org/docs/development/contributing_environment.html#creating-an-environment-without-docker) should then refer to the newly created section.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46205/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46205/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46204',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46204/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46204/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46204/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46204',
#   'id': 1157540646,
#   'node_id': 'PR_kwDOAA0YD84z2Mzr',
#   'number': 46204,
#   'title': 'PERF: avoid copies in frame[col].fillna(val, inplace=True) GH#46149',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-02T18:20:11Z',
#   'updated_at': '2022-03-03T00:26:58Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46204',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46204',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46204.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46204.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46149\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46204/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46204/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46203',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46203/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46203/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46203/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46203',
#   'id': 1157500304,
#   'node_id': 'I_kwDOAA0YD85E_g2Q',
#   'number': 46203,
#   'title': 'REF: Refactor `Grouping` class to use delegates/polymorphism',
#   'user': {'login': 'NickCrews',
#    'id': 10820686,
#    'node_id': 'MDQ6VXNlcjEwODIwNjg2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10820686?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NickCrews',
#    'html_url': 'https://github.com/NickCrews',
#    'followers_url': 'https://api.github.com/users/NickCrews/followers',
#    'following_url': 'https://api.github.com/users/NickCrews/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NickCrews/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NickCrews/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NickCrews/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NickCrews/orgs',
#    'repos_url': 'https://api.github.com/users/NickCrews/repos',
#    'events_url': 'https://api.github.com/users/NickCrews/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/NickCrews/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-03-02T17:39:53Z',
#   'updated_at': '2022-03-03T00:10:27Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "Hi there! Thanks for the work you're doing.\r\n\r\nI started trying to write a PR to fix https://github.com/pandas-dev/pandas/issues/36327, and that got me into the groupby code. Specifically, the `Grouping` class in core.groupby.grouper. I was thinking that this class could be ripe for a refactor.\r\n\r\nCurrently, this class handles lots of different cases, for example if `self.grouping_vector` is a categorical, or a `Grouper` object, or a general array-like. Also it deals with multi-indexes. With one class handling all these cases, the methods are littered with if-elses to decide the right code path.\r\n\r\nPossible solution: Define an interface for a Grouping, and then each of these different cases implement them differently (eg a CategoricalGrouping, MultiIndexGrouping, etc) Then, instead of calling `Grouping.__init__()` to make your grouping, you create them with a factory method. I think this would greatly simplify reasoning about how a Grouping works.\r\n\r\nThis seemed likely that someone has already thought of this, so I wanted to check. I haven't tried implementing it yet, so I might be missing something that makes this a bad idea. If people think this seems like a good idea then I could write a PR for it. Tagging @jbrockmendel since it looks like they have done a lot of refactoring in there already. Thank you!",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46203/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46203/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46202',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46202/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46202/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46202/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46202',
#   'id': 1157424124,
#   'node_id': 'I_kwDOAA0YD85E_OP8',
#   'number': 46202,
#   'title': "BUG: very slow groupby(col1)[col2].value_counts() for columns of type 'category'",
#   'user': {'login': 'whypandasslow',
#    'id': 100778886,
#    'node_id': 'U_kgDOBgHDhg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100778886?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/whypandasslow',
#    'html_url': 'https://github.com/whypandasslow',
#    'followers_url': 'https://api.github.com/users/whypandasslow/followers',
#    'following_url': 'https://api.github.com/users/whypandasslow/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/whypandasslow/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/whypandasslow/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/whypandasslow/subscriptions',
#    'organizations_url': 'https://api.github.com/users/whypandasslow/orgs',
#    'repos_url': 'https://api.github.com/users/whypandasslow/repos',
#    'events_url': 'https://api.github.com/users/whypandasslow/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/whypandasslow/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 57296398,
#     'node_id': 'MDU6TGFiZWw1NzI5NjM5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Algos',
#     'name': 'Algos',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Non-arithmetic algos: value_counts, factorize, sorting, isin, clip, shift, diff'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-03-02T16:31:14Z',
#   'updated_at': '2022-03-02T22:51:57Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\n# EXAMPLE 1\r\n\r\nimport numpy as np\r\nimport pandas as pd\r\nimport time\r\n\r\nt0 = time.time()\r\ncol1_possible_values = ["".join(np.random.choice(list("ABCDEFGHIJKLMNOPRSTUVWXYZ"), 20)) for _ in range(700000)]\r\ncol2_possible_values = ["".join(np.random.choice(list("ABCDEFGHIJKLMNOPRSTUVWXYZ"), 10)) for _ in range(860)]\r\n\r\ncol1_values = np.random.choice(col1_possible_values, size=13000000, replace=True)\r\ncol2_values = np.random.choice(col2_possible_values, size=13000000, replace=True)\r\n\r\nsample_df = pd.DataFrame(zip(col1_values, col2_values), columns=["col1", "col2"])\r\nprint(time.time()-t0)\r\n\r\nt0 = time.time()\r\nprocessed_df = sample_df.groupby("col1")["col2"].value_counts().unstack()\r\nprint(time.time()-t0)\r\n\r\n# EXAMPLE 2\r\n\r\nimport numpy as np\r\nimport pandas as pd\r\nimport time\r\n\r\nt0 = time.time()\r\ncol1_possible_values = ["".join(np.random.choice(list("ABCDEFGHIJKLMNOPRSTUVWXYZ"), 20)) for _ in range(700000)]\r\ncol2_possible_values = ["".join(np.random.choice(list("ABCDEFGHIJKLMNOPRSTUVWXYZ"), 10)) for _ in range(860)]\r\n\r\ncol1_values = np.random.choice(col1_possible_values, size=13000000, replace=True)\r\ncol2_values = np.random.choice(col2_possible_values, size=13000000, replace=True)\r\n\r\nsample_df = pd.DataFrame(zip(col1_values, col2_values), columns=["col1", "col2"])\r\nsample_df[\'col2\'] = sample_df[\'col2\'].astype(\'category\')\r\nprint(time.time()-t0)\r\n\r\nt0 = time.time()\r\nprocessed_df = sample_df.groupby("col1")["col2"].value_counts().unstack()\r\nprint(time.time()-t0)\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nI have 2022 Macbook Pro M1 Pro, pandas 1.4.1, numpy 1.22.2\r\n\r\nI noticed significant performance drop when trying to perform\r\n\r\nsample_df.groupby("col1")["col2"].value_counts().unstack()\r\n\r\nwhen col2 or both col1 and col2 are of type \'category\' instead of default type \'object\'. Operation in EXAMPLE 1 runs around ~25 seconds on my computer (similar for 2019 Macbook Pro with Intel processor). In EXAMPLE 2 I have run the operation for more than 20 minutes and it still did not finish (on 2019 Macbook Pro with Intel processor running time is similar for EXAMPLE 1 and EXAMPLE 2).\r\n\r\nMoreover, for M1 in EXAMPLE 1, the peak memory usage is around 8-10GB while for EXAMPLE 2 it well exceeds 30GB. \r\n\r\n\r\n\r\n### Expected Behavior\r\n\r\non M1:\r\n\r\nEXAMPLE 1 and EXAMPLE 2 should perform roughly the same as they do on Intel processor.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.9.10.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 21.3.0\r\nVersion          : Darwin Kernel Version 21.3.0: Wed Jan  5 21:37:58 PST 2022; root:xnu-8019.80.24~20/RELEASE_ARM64_T6000\r\nmachine          : arm64\r\nprocessor        : arm\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : None.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.22.2\r\npytz             : 2021.3\r\ndateutil         : 2.8.2\r\npip              : 22.0.3\r\nsetuptools       : 60.9.3\r\nCython           : 0.29.28\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : 3.0.3\r\nIPython          : 8.0.1\r\npandas_datareader: None\r\nbs4              : N ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46202/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46202/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46199',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46199/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46199/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46199/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46199',
#   'id': 1157383588,
#   'node_id': 'PR_kwDOAA0YD84z1r00',
#   'number': 46199,
#   'title': 'Test : Pandas 1.0.5 → 1.1.0 behavior change on DataFrame.apply() where fn returns np.ndarray ',
#   'user': {'login': 'weikhor',
#    'id': 36619387,
#    'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/weikhor',
#    'html_url': 'https://github.com/weikhor',
#    'followers_url': 'https://api.github.com/users/weikhor/followers',
#    'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#    'repos_url': 'https://api.github.com/users/weikhor/repos',
#    'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-02T15:56:55Z',
#   'updated_at': '2022-03-02T16:02:18Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46199',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46199',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46199.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46199.patch',
#    'merged_at': None},
#   'body': '- [x] closes #35517 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46199/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46199/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46198',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46198/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46198/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46198/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46198',
#   'id': 1157362179,
#   'node_id': 'PR_kwDOAA0YD84z1nRh',
#   'number': 46198,
#   'title': ' Add benchmark for indexing with .loc for sorted/unsorted DatetimeIndex',
#   'user': {'login': 'weikhor',
#    'id': 36619387,
#    'node_id': 'MDQ6VXNlcjM2NjE5Mzg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36619387?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/weikhor',
#    'html_url': 'https://github.com/weikhor',
#    'followers_url': 'https://api.github.com/users/weikhor/followers',
#    'following_url': 'https://api.github.com/users/weikhor/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/weikhor/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/weikhor/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/weikhor/subscriptions',
#    'organizations_url': 'https://api.github.com/users/weikhor/orgs',
#    'repos_url': 'https://api.github.com/users/weikhor/repos',
#    'events_url': 'https://api.github.com/users/weikhor/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/weikhor/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-03-02T15:38:34Z',
#   'updated_at': '2022-03-03T14:30:33Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46198',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46198',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46198.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46198.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #38690 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46198/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46198/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46197',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46197/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46197/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46197/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46197',
#   'id': 1156227737,
#   'node_id': 'PR_kwDOAA0YD84zxqcd',
#   'number': 46197,
#   'title': 'BUG: nullable groupby result dtypes',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-03-02T02:28:59Z',
#   'updated_at': '2022-03-02T16:33:56Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46197',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46197',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46197.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46197.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nto match the corresponding non-nullable behavior.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46197/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46197/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46196',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46196/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46196/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46196/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46196',
#   'id': 1155989103,
#   'node_id': 'PR_kwDOAA0YD84zwz7p',
#   'number': 46196,
#   'title': 'REF: simplify groupby.ops',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-03-01T23:58:47Z',
#   'updated_at': '2022-03-03T03:37:31Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/46196',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/46196',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/46196.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/46196.patch',
#    'merged_at': None},
#   'body': 'Inching towards refactoring out special-cased EA methods into EA/EADtype methods.\r\n\r\nI expect this to need some troubleshooting on the 32bit linux build.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46196/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46196/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46195',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46195/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46195/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46195/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/46195',
#   'id': 1155867508,
#   'node_id': 'PR_kwDOAA0YD84zwZAr',
#   'number': 46195,
#   'title': 'DOC: Clarify groupby.first does not use nulls ',
#   'user': {'login': 'NumberPiOso',
#    'id': 46936498,
#    'node_id': 'MDQ6VXNlcjQ2OTM2NDk4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46936498?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NumberPiOso',
#    'html_url': 'https://github.com/NumberPiOso',
#    'followers_url': 'https://api.github.com/users/NumberPiOso/followers',
#    'following_url': 'https://api.github.com/users/NumberPiOso/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/NumberPiOso/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/NumberPiOso/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/NumberPiOso/subscriptions',
#    'organizations_url': 'https://api.github.com/users/NumberPiOso/orgs',
#    'repos_url': 'https://api.github.com/users/NumberPiOso/repos',
#    'events_url': 'https://api.github.com/users/NumberPiOso/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/NumberPiOso/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None}],
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46152/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46152/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46149',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46149/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46149/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46149/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46149',
#   'id': 1150712051,
#   'node_id': 'I_kwDOAA0YD85Elnjz',
#   'number': 46149,
#   'title': 'PERF: Series.fillna (that is part of DataFrame) with inplace=True high memory usage / memory leaking',
#   'user': {'login': 'jukiewiczm',
#    'id': 8179126,
#    'node_id': 'MDQ6VXNlcjgxNzkxMjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8179126?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jukiewiczm',
#    'html_url': 'https://github.com/jukiewiczm',
#    'followers_url': 'https://api.github.com/users/jukiewiczm/followers',
#    'following_url': 'https://api.github.com/users/jukiewiczm/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jukiewiczm/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jukiewiczm/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jukiewiczm/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jukiewiczm/orgs',
#    'repos_url': 'https://api.github.com/users/jukiewiczm/repos',
#    'events_url': 'https://api.github.com/users/jukiewiczm/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jukiewiczm/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2022-02-25T17:58:09Z',
#   'updated_at': '2022-03-02T18:06:10Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this issue exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this issue exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\nI have recently migrated from pandas `1.1.3` to pandas `1.4.1` and I'm experiencing some memory-related issues. The code that used to work just fine is now crashing due to memory limitations.\r\n\r\nReproducible example:\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\narr = np.full((500, 400), np.nan)\r\ndf = pd.DataFrame(arr)\r\n\r\nfor col in df.columns:\r\n    df[col].fillna(-1, inplace=True)\r\n```\r\n\r\nInterestingly enough, this snippet, which I would expect to have bigger memory requirements (as it's not inplace), works just fine:\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\ndf = pd.DataFrame([[np.nan] * 400]*500000)\r\n\r\nfor col in df.columns:\r\n    df[col] = df[col].fillna(-1)\r\n```\r\n\r\nThe real code is obviously more complicated than the example, so I'd like to keep filling NA's column by column and doing this in place. Is that an unintended way of using `fillna` for `DataFrame`'s `Series` or is it a bug?\r\nI don't have any memory profiling applied that I could share, but I can try making one if that's necessary. I've just noticed the code work in old pandas version and doesn't work in the new one, and I can see the memory usage in system's resource monitor.\r\n\r\n### Installed Versions\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 06d230151e6f18fdb8139d09abf539867a8cd481\r\npython           : 3.8.3.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.4.0\r\nVersion          : Darwin Kernel Version 20.4.0: Thu Apr 22 21:46:47 PDT 2021; root:xnu-7195.101.2~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : None.UTF-8\r\n\r\npandas           : 1.4.1\r\nnumpy            : 1.21.0\r\npytz             : 2020.1\r\ndateutil         : 2.8.1\r\npip              : 22.0.3\r\nsetuptools       : 41.2.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.8.6\r\njinja2           : 3.0.3\r\nIPython          : 8.0.1\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : 1.3.2\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.2\r\nnumba            : 0.53.1\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 2.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.5.3\r\nsqlalchemy       : 1.4.11\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n```\r\n\r\n### Prior Performance\r\n\r\nIn pandas 1.1.3 the first snippet works just fine.\r\nBoth snippets also seem to work incomparably faster on the older pandas version.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46149/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46149/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46147',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46147/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46147/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46147/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/46147',
#   'id': 1150218652,
#   'node_id': 'I_kwDOAA0YD85EjvGc',
#   'number': 46147,
#   'title': 'ENH: Enumeration grouping',
#   'user': {'login': 'harahu',
#    'id': 6145801,
#    'node_id': 'MDQ6VXNlcjYxNDU4MDE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6145801?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/harahu',
#    'html_url': 'https://github.com/harahu',
#    'followers_url': 'https://api.github.com/users/harahu/followers',
#    'following_url': 'https://api.github.com/users/harahu/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/harahu/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/harahu/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/harahu/subscriptions',
#    'organizations_url': 'https://api.github.com/users/harahu/orgs',
#    'repos_url': 'https://api.github.com/users/harahu/repos',
#    'events_url': 'https://api.github.com/users/harahu/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/harahu/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2022-02-25T09:17:33Z',
#   'updated_at': '2022-03-02T22:28:50Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '#### Is your feature request related to a problem?\r\n\r\nI wish I could use pandas to do more general split-apply-combine workloads. The split-apply-combine pattern is supported today using [`groupby`](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html) and [windowing operations](https://pandas.pydata.org/pandas-docs/stable/user_guide/window.html). Whereas `groupby` is limited by the fact that every row in your DataFrame has to be mapped to 1-and-only-1 group, windowing operations are limited by having to have the same number of groups as rows in your DataFrame. This make both approaches unsuited for cases where you [want to compute summary statistics for a collection of arbitrary subsets of your data](https://stackoverflow.com/questions/71228107/vectorized-slice-aggregation-in-pandas).\r\n\r\nHere are two examples of situations not covered today:\r\n- Grouping a population dataset by age groups with overlap. Say, ages [0-9, 5-14, 10-19, 15-24, ...].\r\n- Sliding windows with strides between windows > 1. Including non-constant strides.\r\n\r\n#### Describe the solution you\'d like\r\n\r\nI came across a general solution that I really like in a language/tool called `esProc`. I haven\'t tried it in practice, and I know very little about the tool\'s merits, but reading the [documentation on what they call _enumeration grouping_](http://doc.raqsoft.com/esproc/tutorial/dwymjfz.html#_93), had me excited.\r\n\r\nThe idea is similar to `groupby`, but instead of specifying a column to group on, you provide a sequence of conditions, where each condition results in a group, that might or might not overlap other groups. This is pretty powerful, an results in a lot of flexibility.\r\n\r\nNote that this solution doesn\'t really cover the sliding window "stride inflexibility" problem mentioned above, as you don\'t want to have to enumerate the masks that would give you your windows, but it does provide a more flexible alternative to `groupby`. I guess striding should be solved by enhancing the existing windowing APIs.\r\n\r\n#### API breaking implications\r\n\r\nN/A\r\n\r\n#### Describe alternatives you\'ve considered\r\n\r\n- Add a column to the df, where each cell contains a list, enumerating the group memberships of its corresponding row. Then, using `df.explode` to create a df where `groupby` can be used as is. This is not satisfactory, as the `df.explode` call, as the method name suggests, risks being highly memory-inefficient, if there is a lot of group overlap.\r\n\r\n- Concatenating the results of multiple group-bys. This is significantly more verbose and might result in arbitrarily many group-by cols.\r\n\r\n#### Additional context\r\n\r\nMy original motivation for wanting this feature: https://stackoverflow.com/questions/71228107/vectorized-slice-aggregation-in-pandas\r\n\r\nThe `esProc` implementation (I think):\r\n- https://github.com/SPLWare/esProc/blob/1d85ea8a758ecd8d8cec9c1531187871cc19a423/src/main/java/com/scudata/expression/mfn/sequence/Enum.java\r\n- https://github.com/SPLWare/esProc/blob/5cd25c9eddbfef0b30628bcef3ef44aff1afee1e/src/main/java/com/scudata/dm/Sequence.java#L8613-L8743\r\n\r\nHow it could look in `pandas`:\r\n\r\n```python\r\n\r\nstats = df.enum_group(\r\n    [df.age < 10, 5 <= df.age < 15, 10 <= df.age < 20, 15 <= df.age < 25]\r\n).agg({"height": "mean"})\r\n\r\n\r\n```\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46147/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46147/timeline',
#   'performed_via_github_app': None}]

# %%
df1=pd.DataFrame(df,columns=['id','url','repository_url','labels_url','user'])

# %%
len(df1) #len of df1 data frame
# Out:
# 30

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#             id                                                url  \
# 0   1158374398  https://api.github.com/repos/pandas-dev/pandas...
# 1   1157875795  https://api.github.com/repos/pandas-dev/pandas...
# 2   1157835973  https://api.github.com/repos/pandas-dev/pandas...
# 3   1157819010  https://api.github.com/repos/pandas-dev/pandas...
# 4   1157652834  https://api.github.com/repos/pandas-dev/pandas...
# 5   1157540646  https://api.github.com/repos/pandas-dev/pandas...
# 6   1157500304  https://api.github.com/repos/pandas-dev/pandas...
# 7   1157424124  https://api.github.com/repos/pandas-dev/pandas...
# 8   1157383588  https://api.github.com/repos/pandas-dev/pandas...
# 9   1157362179  https://api.github.com/repos/pandas-dev/pandas...
# 10  1156227737  https://api.github.com/repos/pandas-dev/pandas...
# 11  1155989103  https://api.github.com/repos/pandas-dev/pandas...
# 12  1155867508  https://api.github.com/repos/pandas-dev/pandas...
# 13  1154543878  https://api.github.com/repos/pandas-dev/pandas...
# 14  1154522327  https://api.github.com/repos/pandas-dev/pandas...
# 15  1154193534  https://api.github.com/repos/pandas-dev/pandas...
# 16  1153888271  https://api.github.com/repos/pandas-dev/pandas...
# 17  1153565414  https://api.github.com/repos/pandas-dev/pandas...
# 18  1153468610  https://api.github.com/repos/pandas-dev/pandas...
# 19  1153437571  https://api.github.com/repos/pandas-dev/pandas...
# 20  1153397978  https://api.github.com/repos/pandas-dev/pandas...
# 21  1153244393  https://api.github.com/repos/pandas-dev/pandas...
# 22  1152939467  https://api.github.com/repos/pandas-dev/pandas...
# 23  1152647346  https://api.github.com/repos/pandas-dev/pandas...
# 24  1151916356  https://api.github.com/repos/pandas-dev/pandas...
# 25  1150920527  https://api.github.com/repos/pandas-dev/pandas...
# 26  1150876170  https://api.github.com/repos/pandas-dev/pandas...
# 27  1150754239  https://api.github.com/repos/pandas-dev/pandas...
# 28  1150712051  https://api.github.com/repos/pandas-dev/pandas...
# 29  1150218652  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'moojen', 'id': 18547401, 'node_id':...
# 1   {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 2   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3   {'login': 'NickCrews', 'id': 10820686, 'node_i...
# 4   {'login': 'rendner', 'id': 414652, 'node_id': ...
# 5   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 6   {'login': 'NickCrews', 'id': 10820686, 'node_i...
# 7   {'login': 'whypandasslow', 'id': 100778886, 'n...
# 8   {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 9   {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 10  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 11  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 12  {'login': 'NumberPiOso', 'id': 46936498, 'node...
# 13  {'login': 'theinexorable', 'id': 51996504, 'no...
# 14  {'login': 'RagBlufThim', 'id': 25440862, 'node...
# 15  {'login': 'johannes-mueller', 'id': 5902745, '...
# 16  {'login': 'tritemio', 'id': 4156237, 'node_id'...
# 17  {'login': 'mach881040', 'id': 100502242, 'node...
# 18  {'login': 'fractionalhare', 'id': 10540830, 'n...
# 19  {'login': 'macsakow', 'id': 10297014, 'node_id...
# 20  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 21  {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 22  {'login': 'J0', 'id': 8011761, 'node_id': 'MDQ...
# 23  {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 24  {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 25  {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 26  {'login': 'milotoor', 'id': 4667801, 'node_id'...
# 27  {'login': 'tehunter', 'id': 7980666, 'node_id'...
# 28  {'login': 'jukiewiczm', 'id': 8179126, 'node_i...
# 29  {'login': 'harahu', 'id': 6145801, 'node_id': ...

# %%
new=[]
for i in df1['user']:
    new.append(i)
df2=pd.DataFrame(new)

# %%
len(df2)
# Out:
# 30

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2
# Out:
#                login         id               node_id  \
# 0             moojen   18547401  MDQ6VXNlcjE4NTQ3NDAx
# 1         rhshadrach   45562402  MDQ6VXNlcjQ1NTYyNDAy
# 2       jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 3          NickCrews   10820686  MDQ6VXNlcjEwODIwNjg2
# 4            rendner     414652  MDQ6VXNlcjQxNDY1Mg==
# 5       jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 6          NickCrews   10820686  MDQ6VXNlcjEwODIwNjg2
# 7      whypandasslow  100778886          U_kgDOBgHDhg
# 8            weikhor   36619387  MDQ6VXNlcjM2NjE5Mzg3
# 9            weikhor   36619387  MDQ6VXNlcjM2NjE5Mzg3
# 10      jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 11      jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 12       NumberPiOso   46936498  MDQ6VXNlcjQ2OTM2NDk4
# 13     theinexorable   51996504  MDQ6VXNlcjUxOTk2NTA0
# 14       RagBlufThim   25440862  MDQ6VXNlcjI1NDQwODYy
# 15  johannes-mueller    5902745  MDQ6VXNlcjU5MDI3NDU=
# 16          tritemio    4156237  MDQ6VXNlcjQxNTYyMzc=
# 17        mach881040  100502242          U_kgDOBf2K4g
# 18    fractionalhare   10540830  MDQ6VXNlcjEwNTQwODMw
# 19          macsakow   10297014  MDQ6VXNlcjEwMjk3MDE0
# 20            Dr-Irv   15113894  MDQ6VXNlcjE1MTEzODk0
# 21           weikhor   36619387  MDQ6VXNlcjM2NjE5Mzg3
# 22                J0    8011761  MDQ6VXNlcjgwMTE3NjE=
# 23        lukemanley    8519523  MDQ6VXNlcjg1MTk1MjM=
# 24           weikhor   36619387  MDQ6VXNlcjM2NjE5Mzg3
# 25        lukemanley    8519523  MDQ6VXNlcjg1MTk1MjM=
# 26          milotoor    4667801  MDQ6VXNlcjQ2Njc4MDE=
# 27          tehunter    7980666  MDQ6VXNlcjc5ODA2NjY=
# 28        jukiewiczm    8179126  MDQ6VXNlcjgxNzkxMjY=
# 29            harahu    6145801  MDQ6VXNlcjYxNDU4MDE=
#
#                                            avatar_url gravatar_id  \
# 0   https://avatars.githubusercontent.com/u

# 15  https://api.github.com/users/johannes-mueller/...
# 16  https://api.github.com/users/tritemio/subscrip...
# 17  https://api.github.com/users/mach881040/subscr...
# 18  https://api.github.com/users/fractionalhare/su...
# 19  https://api.github.com/users/macsakow/subscrip...
# 20  https://api.github.com/users/Dr-Irv/subscriptions
# 21  https://api.github.com/users/weikhor/subscript...
# 22      https://api.github.com/users/J0/subscriptions
# 23  https://api.github.com/users/lukemanley/subscr...
# 24  https://api.github.com/users/weikhor/subscript...
# 25  https://api.github.com/users/lukemanley/subscr...
# 26  https://api.github.com/users/milotoor/subscrip...
# 27  https://api.github.com/users/tehunter/subscrip...
# 28  https://api.github.com/users/jukiewiczm/subscr...
# 29  https://api.github.com/users/harahu/subscriptions
#
#                                     organizations_url  \
# 0            https://api.github.com/users/moojen/orgs
# 1        https://api.github.com/users/rhshadrach/orgs
# 2      https://api.github.com/users/jbrockmendel/orgs
# 3         https://api.github.com/users/NickCrews/orgs
# 4           https://api.github.com/users/rendner/orgs
# 5      https://api.github.com/users/jbrockmendel/orgs
# 6         https://api.github.com/users/NickCrews/orgs
# 7     https://api.github.com/users/whypandasslow/orgs
# 8           https://api.github.com/users/weikhor/orgs
# 9           https://api.github.com/users/weikhor/orgs
# 10     https://api.github.com/users/jbrockmendel/orgs
# 11     https://api.github.com/users/jbrockmendel/orgs
# 12      https://api.github.com/users/NumberPiOso/orgs
# 13    https://api.github.com/users/theinexorable/orgs
# 14      https://api.github.com/users/RagBlufThim/orgs
# 15  https://api.github.com/users/johannes-mueller/...
# 16         https://api.github.com/users/tritemio/orgs
# 17       https://api.github.com/users/mach881040/orgs
# 18   https://api.github.com/users/fractionalhare/orgs
# 19         https://api.github.com/users/macsakow/orgs
# 20           https://api.github.com/users/Dr-Irv/orgs
# 21          https://api.github.com/users/weikhor/orgs
# 22               https://api.github.com/users/J0/orgs
# 23       https://api.github.com/users/lukemanley/orgs
# 24          https://api.github.com/users/weikhor/orgs
# 25       https://api.github.com/users/lukemanley/orgs
# 26         https://api.github.com/users/milotoor/orgs
# 27         https://api.github.com/users/tehunter/orgs
# 28       https://api.github.com/users/jukiewiczm/orgs
# 29           https://api.github.com/users/harahu/orgs
#
#                                             repos_url  \
# 0           https://api.github.com/users/moojen/repos
# 1       https://api.github.com/users/rhshadrach/repos
# 2     https://api.github.com/users/jbrockmendel/repos
# 3        https://api.github.com/users/NickCrews/repos
# 4          https://api.github.com/users/rendner/repos
# 5     https://api.github.com/users/jbrockmendel/repos
# 6        https://api.github.com/users/NickCrews/repos
# 7    https://api.github.com/users/whypandasslow/repos
# 8          https://api.github.com/users/weikhor/repos
# 9          https://api.github.com/users/weikhor/repos
# 10    https://api.github.com/users/jbrockmendel/repos
# 11    https://api.github.com/users/jbrockmendel/repos
# 12     https://api.github.com/users/NumberPiOso/repos
# 13   https://api.github.com/users/theinexorable/repos
# 14     https://api.github.com/users/RagBlufThim/repos
# 15  https://api.github.com/users/johannes-mueller/...
# 16        https://api.github.com/users/tritemio/repos
# 17      https://api.github.com/users/mach881040/repos
# 18  https://api.github.com/users/fractionalhare/repos
# 19        https://api.github.com/users/macsakow/repos
# 20          https://api.github.com/users/Dr-Irv/repos
# 21         https://api.github.com/users/weikhor/repos
# 22              https://api.github.com/users/J0/repos
# 23      https://api.github.com/users/lukemanley/repos
# 24         https://api.github.com/users/weikhor/repos
# 25      https://api.github.com/users/lukemanley/repos
# 26        https://api.github.com/users/milotoor/repos
# 27        https://api.github.com/users/tehunter/repos
# 28      https://api.github.com/users/jukiewiczm/repos
# 29          https://api.github.com/users/harahu/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/moojen/events{/pr...
# 1   https://api.github.com/users/rhshadrach/events...
# 2   https://api.github.com/users/jbrockmendel/even...
# 3   https://api.github.com/users/NickCrews/events{...
# 4   https://api.github.com/users/rendner/events{/p...
# 5   https://api.github.com/users/jbrockmendel/even...
# 6   https://api.github.com/users/NickCrews/events{...
# 7   https://api.github.com/users/whypandasslow/eve...
# 8   https://api.github.com/users/weikhor/events{/p...
# 9   https://api.github.com/users/weikhor/events{/p...
# 10  https://api.github.com/users/jbrockmendel/even...
# 11  https://api.github.com/users/jbrockmendel/even...
# 12  https://api.github.com/users/NumberPiOso/event...
# 13  https://api.github.com/users/theinexorable/eve...
# 14  https://api.github.com/users/RagBlufThim/event...
# 15  https://api.github.com/users/johannes-mueller/...
# 16  https://api.github.com/users/tritemio/events{/...
# 17  https://api.github.com/users/mach881040/events...
# 18  https://api.github.com/users/fractionalhare/ev...
# 19  https://api.github.com/users/macsakow/events{/...
# 20  https://api.github.com/users/Dr-Irv/events{/pr...
# 21  https://api.github.com/users/weikhor/events{/p...
# 22   https://api.github.com/users/J0/events{/privacy}
# 23  https://api.github.com/users/lukemanley/events...
# 24  https://api.github.com/users/weikhor/events{/p...
# 25  https://api.github.com/users/lukemanley/events...
# 26  https://api.github.com/users/milotoor/events{/...
# 27  https://api.github.com/users/tehunter/events{/...
# 28  https://api.github.com/users/jukiewiczm/events...
# 29  https://api.github.com/users/harahu/events{/pr...
#
#                                   received_events_url  type  site_admin
# 0   https://api.github.com/users/moojen/received_e...  User       False
# 1   https://api.github.com/users/rhshadrach/receiv...  User       False
# 2   https://api.github.com/users/jbrockmendel/rece...  User       False
# 3   https://api.github.com/users/NickCrews/receive...  User       False
# 4   https://api.github.com/users/rendner/received_...  User       False
# 5   https://api.github.com/users/jbrockmendel/rece...  User       False
# 6   https://api.github.com/users/NickCrews/receive...  User       False
# 7   https://api.github.com/users/whypandasslow/rec...  User       False
# 8   https://api.github.com/users/weikhor/received_...  User       False
# 9   https://api.github.com/users/weikhor/received_...  User       False
# 10  https://api.github.com/users/jbrockmendel/rece...  User       False
# 11  https://api.github.com/users/jbrockmendel/rece...  User       False
# 12  https://api.github.com/users/NumberPiOso/recei...  User       False
# 13  https://api.github.com/users/theinexorable/rec...  User       False
# 14  https://api.github.com/users/RagBlufThim/recei...  User       False
# 15  https://api.github.com/users/johannes-mueller/...  User       False
# 16  https://api.github.com/users/tritemio/received...  User       False
# 17  https://api.github.com/users/mach881040/receiv...  User       False
# 18  https://api.github.com/users/fractionalhare/re...  User       False
# 19  https://api.github.com/users/macsakow/received...  User       False
# 20  https://api.github.com/users/Dr-Irv/received_e...  User       False
# 21  https://api.github.com/users/weikhor/received_...  User       False
# 22    https://api.github.com/users/J0/received_events  User       False
# 23  https://api.github.com/users/lukemanley/receiv...  User       False
# 24  https://api.github.com/users/weikhor/received_...  User       False
# 25  https://api.github.com/users/lukemanley/receiv...  User       False
# 26  https://api.github.com/users/milotoor/received...  User       False
# 27  https://api.github.com/users/tehunter/received...  User       False
# 28  https://api.github.com/users/jukiewiczm/receiv...  User       False
# 29  https://api.github.com/users/harahu/received_e...  User       False

# %%
result = pd.concat([df1, df2], axis=1, join='inner')

# %%
result
# Out:
#             id                                                url  \
# 0   1158374398  https://api.github.com/repos/pandas-dev/pandas...
# 1   1157875795  https://api.github.com/repos/pandas-dev/pandas...
# 2   1157835973  https://api.github.com/repos/pandas-dev/pandas...
# 3   1157819010  https://api.github.com/repos/pandas-dev/pandas...
# 4   1157652834  https://api.github.com/repos/pandas-dev/pandas...
# 5   1157540646  https://api.github.com/repos/pandas-dev/pandas...
# 6   1157500304  https://api.github.com/repos/pandas-dev/pandas...
# 7   1157424124  https://api.github.com/repos/pandas-dev/pandas...
# 8   1157383588  https://api.github.com/repos/pandas-dev/pandas...
# 9   1157362179  https://api.github.com/repos/pandas-dev/pandas...
# 10  1156227737  https://api.github.com/repos/pandas-dev/pandas...
# 11  1155989103  https://api.github.com/repos/pandas-dev/pandas...
# 12  1155867508  https://api.github.com/repos/pandas-dev/pandas...
# 13  1154543878  https://api.github.com/repos/pandas-dev/pandas...
# 14  1154522327  https://api.github.com/repos/pandas-dev/pandas...
# 15  1154193534  https://api.github.com/repos/pandas-dev/pandas...
# 16  1153888271  https://api.github.com/repos/pandas-dev/pandas...
# 17  1153565414  https://api.github.com/repos/pandas-dev/pandas...
# 18  1153468610  https://api.github.com/repos/pandas-dev/pandas...
# 19  1153437571  https://api.github.com/repos/pandas-dev/pandas...
# 20  1153397978  https://api.github.com/repos/pandas-dev/pandas...
# 21  1153244393  https://api.github.com/repos/pandas-dev/pandas...
# 22  1152939467  https://api.github.com/repos/pandas-dev/pandas...
# 23  1152647346  https://api.github.com/repos/pandas-dev/pandas...
# 24  1151916356  https://api.github.com/repos/pandas-dev/pandas...
# 25  1150920527  https://api.github.com/repos/pandas-dev/pandas...
# 26  1150876170  https://api.github.com/repos/pandas-dev/pandas...
# 27  1150754239  https://api.github.com/repos/pandas-dev/pandas...
# 28  1150712051  https://api.github.com/repos/pandas-dev/pandas...
# 29  1150218652  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user             login  \
# 0   {'login': 'moojen', 'id': 18547401, 'node_id':...            moojen
# 1   {'login': 'rhshadrach', 'id': 45562402, 'node_...        rhshadrach
# 2   {'login': 'jbrockmendel', 'id': 8078968, 'node...      jbrockmendel
# 3   {'login': 'NickCrews', 'id': 10820686, 'node_i...         NickCrews
# 4   {'login': 'rendner', 'id': 414652, 'node_id': ...           rendner
# 5   {'login': 'jbrockmendel', 'id': 8078968, 'node...      jbrockmendel
# 6   {'login': 'NickCrews', 'id': 10820686, 'node_i...         NickCrews
# 7   {'login': 'whypandasslow', 'id': 100778886, 'n...     whypandasslow
# 8   {'login': 'weikhor', 'id': 36619387, 'node_id'...           weikhor
# 9   {'login': 'weikhor', 'id': 36619387, 'node_id'...           weikhor
# 10  {'login': 'jbrockmendel', 'id': 8078968, 'node...      jbrockmendel
# 11  {'login': 'jbrockmendel', 'id': 8078968, 'node...      jbrockmendel
# 12  {'login': 'NumberPiOso', 'id': 46936498, 'node...       NumberPiOso
# 13  {'login': 'theinexorable', 'id': 51996504, 'no...     theinexorable
# 14  {'login': 'RagBlufThim', 'id': 25440862, 'node...       RagBlufThim
# 15  {'login': 'johannes-mueller', 'id': 5902745, '...  johannes-mueller
# 16  {'login': 'tritemio', 'id': 4156237, 'node_id'...          tritemio
# 17  {'login': 'mach881040', 'id': 100502242, 'node...        mach881040
# 18  {'login': 'fractionalhare', 'id': 10540830, 'n...    fractionalhare
# 19  {'login': 'macsakow', 'id': 10297014, 'node_id...          macsakow
# 20  {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...            Dr-Irv
# 21  {'login': 'weikhor', 'id': 36619387, 'node_id'...           weikhor
# 22  {'login': 'J0', 'id': 8011761, 'node_id': 'MDQ...                J0
# 23  {'login': 'lukemanley', 'id': 8519523, 'node_i...        lukemanley
# 24  {'login': 'weikhor', 'id': 36619387, 'node_id'...           weikhor
# 25  {'login': 'lukemanley', 'id': 8519523, 'node_i...        lukemanley
# 26  {'login': 'milotoor', 'id': 4667801, 'node_id'...          milotoor
# 27  {'login': 'tehunter', 'id': 7980666, 'node_id'...          tehunter
# 28  {'login': 'jukiewiczm', 'id': 8179126, 'node_i...        jukiewiczm
# 29  {'login': 'harahu', 'id': 6145801, 'node_id': ...            harahu
#
#            id               node_id  \
# 0    18547401  MDQ6VXNlcjE4NTQ3NDAx
# 1    45562402  MDQ6VXNlcjQ1NTYyNDAy
# 2     8078968  MDQ6VXNlcjgwNzg5Njg=
# 3    10820686  MDQ6VXNlcjEwODIwNjg2
# 4      414652  MDQ6VXNlcjQxNDY1Mg==
# 5     8078968  MDQ6VXNlcjgwNzg5Njg=
# 6    10820686  MDQ6VXNlcjEwODIwNjg2
# 7   100778886          U_kgDOBgHDhg
# 8    36619387  MDQ6VXNlcjM2NjE5Mzg3
# 9    36619387  MDQ6VXNlcjM2NjE5Mzg3
# 10    8078968  MDQ6VXNlcjgwNzg5Njg=
# 11    8078968  MDQ6VXNlcjgwNzg5Njg=
# 12   46936498  MDQ6VXNlcjQ2OTM2NDk4
# 13   51996504  MDQ6VXNlcjUxOTk2NTA0
# 14   25440862  MDQ6VXNlcjI1NDQwODYy
# 15    5902745  MDQ6VXNlcjU5MDI3NDU=
# 16    4156237  MDQ6VXNlcjQxNTYyMzc=
# 17  100502242          U_kgDOBf2K4g
# 18   10540830  MDQ6VXNlcjEwNTQwODMw
# 19   10297014  MDQ6VXNlcjEwMjk3MDE0
# 20   15113894  MDQ6VXNlcjE1MTEzODk0
# 21   36619387  MDQ6VXNlcjM2NjE5Mzg3
# 22    8011761  MDQ6VXNlcjgwMTE3NjE=
# 23    8519523  MDQ6VXNlcjg1MTk1MjM=
# 24   36619387  MDQ6VXNlcjM2NjE5Mzg3
# 25    8519523  MDQ6VXNlcjg1MTk1MjM=
# 26    4667801  MDQ6VXNlcjQ2Njc4MDE=
# 27    7980666  MDQ6VXNlcjc5ODA2NjY=
# 28    8179126  MDQ6VXNlcjgxNzkxMjY=
# 29    6145801  MDQ6VXNlcjYxNDU4MDE=
#
#                                            avatar_url gravatar_id  ...  \
# 0   https://avatars.githubusercontent.com/u/185474...              ...
# 1   https://avatars.githubusercontent.com/u/455624...              ...
# 2   https://avatars.githubusercontent.com/u/807896...              ...
# 3   https://avatars.githubusercontent.com/u/108206...              ...
# 4   https://avatars.githubusercontent.com/u/414652...              ...
# 5   https://avatars.githubusercontent.com/u/807896...              ...

# 15  https://api.github.com/users/johannes-mueller/...
# 16  https://api.github.com/users/tritemio/subscrip...
# 17  https://api.github.com/users/mach881040/subscr...
# 18  https://api.github.com/users/fractionalhare/su...
# 19  https://api.github.com/users/macsakow/subscrip...
# 20  https://api.github.com/users/Dr-Irv/subscriptions
# 21  https://api.github.com/users/weikhor/subscript...
# 22      https://api.github.com/users/J0/subscriptions
# 23  https://api.github.com/users/lukemanley/subscr...
# 24  https://api.github.com/users/weikhor/subscript...
# 25  https://api.github.com/users/lukemanley/subscr...
# 26  https://api.github.com/users/milotoor/subscrip...
# 27  https://api.github.com/users/tehunter/subscrip...
# 28  https://api.github.com/users/jukiewiczm/subscr...
# 29  https://api.github.com/users/harahu/subscriptions
#
#                                     organizations_url  \
# 0            https://api.github.com/users/moojen/orgs
# 1        https://api.github.com/users/rhshadrach/orgs
# 2      https://api.github.com/users/jbrockmendel/orgs
# 3         https://api.github.com/users/NickCrews/orgs
# 4           https://api.github.com/users/rendner/orgs
# 5      https://api.github.com/users/jbrockmendel/orgs
# 6         https://api.github.com/users/NickCrews/orgs
# 7     https://api.github.com/users/whypandasslow/orgs
# 8           https://api.github.com/users/weikhor/orgs
# 9           https://api.github.com/users/weikhor/orgs
# 10     https://api.github.com/users/jbrockmendel/orgs
# 11     https://api.github.com/users/jbrockmendel/orgs
# 12      https://api.github.com/users/NumberPiOso/orgs
# 13    https://api.github.com/users/theinexorable/orgs
# 14      https://api.github.com/users/RagBlufThim/orgs
# 15  https://api.github.com/users/johannes-mueller/...
# 16         https://api.github.com/users/tritemio/orgs
# 17       https://api.github.com/users/mach881040/orgs
# 18   https://api.github.com/users/fractionalhare/orgs
# 19         https://api.github.com/users/macsakow/orgs
# 20           https://api.github.com/users/Dr-Irv/orgs
# 21          https://api.github.com/users/weikhor/orgs
# 22               https://api.github.com/users/J0/orgs
# 23       https://api.github.com/users/lukemanley/orgs
# 24          https://api.github.com/users/weikhor/orgs
# 25       https://api.github.com/users/lukemanley/orgs
# 26         https://api.github.com/users/milotoor/orgs
# 27         https://api.github.com/users/tehunter/orgs
# 28       https://api.github.com/users/jukiewiczm/orgs
# 29           https://api.github.com/users/harahu/orgs
#
#                                             repos_url  \
# 0           https://api.github.com/users/moojen/repos
# 1       https://api.github.com/users/rhshadrach/repos
# 2     https://api.github.com/users/jbrockmendel/repos
# 3        https://api.github.com/users/NickCrews/repos
# 4          https://api.github.com/users/rendner/repos
# 5     https://api.github.com/users/jbrockmendel/repos
# 6        https://api.github.com/users/NickCrews/repos
# 7    https://api.github.com/users/whypandasslow/repos
# 8          https://api.github.com/users/weikhor/repos
# 9          https://api.github.com/users/weikhor/repos
# 10    https://api.github.com/users/jbrockmendel/repos
# 11    https://api.github.com/users/jbrockmendel/repos
# 12     https://api.github.com/users/NumberPiOso/repos
# 13   https://api.github.com/users/theinexorable/repos
# 14     https://api.github.com/users/RagBlufThim/repos
# 15  https://api.github.com/users/johannes-mueller/...
# 16        https://api.github.com/users/tritemio/repos
# 17      https://api.github.com/users/mach881040/repos
# 18  https://api.github.com/users/fractionalhare/repos
# 19        https://api.github.com/users/macsakow/repos
# 20          https://api.github.com/users/Dr-Irv/repos
# 21         https://api.github.com/users/weikhor/repos
# 22              https://api.github.com/users/J0/repos
# 23      https://api.github.com/users/lukemanley/repos
# 24         https://api.github.com/users/weikhor/repos
# 25      https://api.github.com/users/lukemanley/repos
# 26        https://api.github.com/users/milotoor/repos
# 27        https://api.github.com/users/tehunter/repos
# 28      https://api.github.com/users/jukiewiczm/repos
# 29          https://api.github.com/users/harahu/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/moojen/events{/pr...
# 1   https://api.github.com/users/rhshadrach/events...
# 2   https://api.github.com/users/jbrockmendel/even...
# 3   https://api.github.com/users/NickCrews/events{...
# 4   https://api.github.com/users/rendner/events{/p...
# 5   https://api.github.com/users/jbrockmendel/even...
# 6   https://api.github.com/users/NickCrews/events{...
# 7   https://api.github.com/users/whypandasslow/eve...
# 8   https://api.github.com/users/weikhor/events{/p...
# 9   https://api.github.com/users/weikhor/events{/p...
# 10  https://api.github.com/users/jbrockmendel/even...
# 11  https://api.github.com/users/jbrockmendel/even...
# 12  https://api.github.com/users/NumberPiOso/event...
# 13  https://api.github.com/users/theinexorable/eve...
# 14  https://api.github.com/users/RagBlufThim/event...
# 15  https://api.github.com/users/johannes-mueller/...
# 16  https://api.github.com/users/tritemio/events{/...
# 17  https://api.github.com/users/mach881040/events...
# 18  https://api.github.com/users/fractionalhare/ev...
# 19  https://api.github.com/users/macsakow/events{/...
# 20  https://api.github.com/users/Dr-Irv/events{/pr...
# 21  https://api.github.com/users/weikhor/events{/p...
# 22   https://api.github.com/users/J0/events{/privacy}
# 23  https://api.github.com/users/lukemanley/events...
# 24  https://api.github.com/users/weikhor/events{/p...
# 25  https://api.github.com/users/lukemanley/events...
# 26  https://api.github.com/users/milotoor/events{/...
# 27  https://api.github.com/users/tehunter/events{/...
# 28  https://api.github.com/users/jukiewiczm/events...
# 29  https://api.github.com/users/harahu/events{/pr...
#
#                                   received_events_url  type site_admin
# 0   https://api.github.com/users/moojen/received_e...  User      False
# 1   https://api.github.com/users/rhshadrach/receiv...  User      False
# 2   https://api.github.com/users/jbrockmendel/rece...  User      False
# 3   https://api.github.com/users/NickCrews/receive...  User      False
# 4   https://api.github.com/users/rendner/received_...  User      False
# 5   https://api.github.com/users/jbrockmendel/rece...  User      False
# 6   https://api.github.com/users/NickCrews/receive...  User      False
# 7   https://api.github.com/users/whypandasslow/rec...  User      False
# 8   https://api.github.com/users/weikhor/received_...  User      False
# 9   https://api.github.com/users/weikhor/received_...  User      False
# 10  https://api.github.com/users/jbrockmendel/rece...  User      False
# 11  https://api.github.com/users/jbrockmendel/rece...  User      False
# 12  https://api.github.com/users/NumberPiOso/recei...  User      False
# 13  https://api.github.com/users/theinexorable/rec...  User      False
# 14  https://api.github.com/users/RagBlufThim/recei...  User      False
# 15  https://api.github.com/users/johannes-mueller/...  User      False
# 16  https://api.github.com/users/tritemio/received...  User      False
# 17  https://api.github.com/users/mach881040/receiv...  User      False
# 18  https://api.github.com/users/fractionalhare/re...  User      False
# 19  https://api.github.com/users/macsakow/received...  User      False
# 20  https://api.github.com/users/Dr-Irv/received_e...  User      False
# 21  https://api.github.com/users/weikhor/received_...  User      False
# 22    https://api.github.com/users/J0/received_events  User      False
# 23  https://api.github.com/users/lukemanley/receiv...  User      False
# 24  https://api.github.com/users/weikhor/received_...  User      False
# 25  https://api.github.com/users/lukemanley/receiv...  User      False
# 26  https://api.github.com/users/milotoor/received...  User      False
# 27  https://api.github.com/users/tehunter/received...  User      False
# 28  https://api.github.com/users/jukiewiczm/receiv...  User      False
# 29  https://api.github.com/users/harahu/received_e...  User      False
#
# [30 rows x 23 columns]
