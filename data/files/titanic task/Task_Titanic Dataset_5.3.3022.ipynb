# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Find out male and female passenger onborded
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
# How many survived
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# What is name of the preson who is eldest
df[df['Age'] < 1]['Name']
# Out:
# 78       Caldwell, Master. Alden Gates
# 305     Allison, Master. Hudson Trevor
# 469      Baclini, Miss. Helene Barbara
# 644             Baclini, Miss. Eugenie
# 755          Hamalainen, Master. Viljo
# 803    Thomas, Master. Assad Alexander
# 831    Richards, Master. George Sibley
# Name: Name, dtype: object

# %%
# How many passenger do we have first, second and third class
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# How many paerson we have whos name start from "s"
df['Name'] == index[0] == 'S'

# %%
# try to create new column with summation of "sipsp" and "purch"
df['Sib_Parchh']=df['SibSp']+df['Parch']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# how many person do we have below 25 age
df[df['Age'] < 25.0]['Name']
# Out:
# 0                  Braund, Mr. Owen Harris
# 7           Palsson, Master. Gosta Leonard
# 9      Nasser, Mrs. Nicholas (Adele Achem)
# 10         Sandstrom, Miss. Marguerite Rut
# 12          Saundercock, Mr. William Henry
#                       ...
# 875       Najib, Miss. Adele Kiamie "Jane"
# 876          Gustafsson, Mr. Alfred Ossian
# 877                   Petroff, Mr. Nedelio
# 882           Dahlberg, Miss. Gerda Ulrika
# 887           Graham, Miss. Margaret Edith
# Name: Name, Length: 278, dtype: object

# %%
# How many prson died whose age is less than 40
df.Name[(df.Survived == 0) & (df.Age < 40)]
# Out:
# 0                   Braund, Mr. Owen Harris
# 4                  Allen, Mr. William Henry
# 7            Palsson, Master. Gosta Leonard
# 12           Saundercock, Mr. William Henry
# 13              Andersson, Mr. Anders Johan
#                        ...
# 883           Banfield, Mr. Frederick James
# 884                  Sutehall, Mr. Henry Jr
# 885    Rice, Mrs. William (Margaret Norton)
# 886                   Montvila, Rev. Juozas
# 890                     Dooley, Mr. Patrick
# Name: Name, Length: 322, dtype: object
