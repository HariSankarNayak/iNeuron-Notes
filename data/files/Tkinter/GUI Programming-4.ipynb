# %% [markdown]
# GUI Programming-V
#
# Using bind( ) Method
# Using Entry Widget

# %% [markdown]
# Python provides us another more powerful way of event handling using a method called bind( ).
#
# This method is included in all the widgets and has the following syntax:
#
# Syntax:
# <obj_name>.bind(“<event>”,handler)
#
# event : A case sensitive string that contains details about which event to listen for, this must be given in the following format:"<modifier>".
#
# handler : The name of the function to call when the event occurs

# %% [markdown]
# The function name which is passed as second argument to the method bind() should have the following syntax:
#
# Syntax:
#
# def fun_name(e):
#     # some code

# %% [markdown]
# This argument is compulsory as Python passes it while calling the event handler function. It is of class tkinter.Event

# %% [markdown]
# Write an app that contains a Button and as soon as it is clicked using any  Mouse Button , the background color of the window should change to red
#
# Before Button Click	After Button Click

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tkinter import *

root = Tk()
root.geometry('200x200')
b1=Button(root,text="Click Me")
b1.pack()
root.mainloop()

# %%
from tkinter import *

root = Tk()
root.geometry('200x200')
buttonCommit = Button(root, height=1, width=10, text="button",command=lambda: display_lbox_all(root))
buttonCommit.pack()
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nayak\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\nayak\AppData\Local\Temp\ipykernel_8864\2681131887.py", line 5, in <lambda>
#     buttonCommit = Button(root, height=1, width=10, text="button",command=lambda: display_lbox_all(root))
# NameError: name 'display_lbox_all' is not defined

# %%
import tkinter
def action():
    root.config(bg="red")
root = tkinter.Tk()
root.geometry("400x400")
b1 = tkinter.Button(root, text="Click me", command=action)
b1.pack()
root.mainloop()

# %%
from tkinter import *

def changecolor(e):
    root.config(bg="red")

root = Tk()
root.geometry('200x200')
b1=Button(root,text="Click Me")
b1.bind("<Button-1>",changecolor)
b1.pack()
root.mainloop()

# %%
from tkinter import *
root = Tk()
root.geometry('200x200')
b1=Button(root,text="Click Me")
b1.bind("<Button>",lambda e: root.config(bg="red"))
b1.pack()
root.mainloop()

# %% [markdown]
# b1.bind("<Button>",changecolor)
#
# The first argument is type of event that we wish to bind and it can be user actions like Button (for mouse clicks using any mouse button), and Key( for key press), or many other events like  Enter, Leave,FocusIn,FocusOut etc.
#
# The second argument is the function name to be called when the event occurs

# %% [markdown]
# def changecolor(e):
#     root.config(bg="red")
#
#
# The argument e is called event object and it is a standard Python object instance, with a number of attributes describing the event.

# %% [markdown]
# Write an app that contains a Button and as soon as the Button is left clicked it should change the background color of the window to red and if it is right clicked the background color of the window should be come blue
#
# “<Button>”
# Any mouse button pressed
# “<Button-1>”
# Left mouse button pressed
# “<Button-2>”
# Middle mouse button pressed
# “<Button-3>”
# Right mouse button pressed

# %%
from tkinter import *
def changecolor(e):
    root.config(bg='red')
    
def changecolor1(e):
    root.config(bg='blue')
root=Tk()
root.geometry('200x200')
b1=Button(root,text='click me')
b1.bind("<Button-1>",changecolor)
b1.bind("<Button-3>",changecolor1)
b1.pack()

root.mainloop()

# %%
def changecolorred(e):
    root.config(bg='red')
    
def changecolorblue(e):
    root.config(bg='blue')

#only left mouse button
import tkinter
root = tkinter.Tk()
root.geometry('350x250')
buttonCommit = tkinter.Button(root, height=1, width=10, text="click")
buttonCommit.bind('<Button-1>',changecolorred)
buttonCommit.bind('<Button-3>',changecolorblue)
buttonCommit.pack()
root.mainloop()

# %%
from tkinter import *
root=Tk()
root.geometry('200x200')

def changecolor(a):
    root.config(bg='red')
def changecolor1(a):
    root.config(bg='blue')   
b1=Button(root,text='Click Me')
b1.bind("<Button-1>",changecolor)
b1.bind("<Button-3>",changecolor1)

b1.pack()
root.mainloop()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tkinter import *

root = Tk()
root.geometry('200x200')
b1=Button(root,text="Click Me")
b1.pack()
root.mainloop()

# %%
from tkinter import *

def leftclick(e):
    root.config(bg="red")

def rightclick(e):
    root.config(bg="blue")

root = Tk()
root.geometry('200x200')
b1=Button(root,text="Click Me")
b1.bind("<Button-1>",leftclick)
b1.bind("<Button-3>",rightclick)
b1.pack()
root.mainloop()

# %%
from tkinter import *

root = Tk()
root.geometry('200x200')
b1=Button(root,text="Click Me")
b1.bind("<Button-1>",lambda e: root.config(bg="red"))
b1.bind("<Button-3>", lambda e: root.config(bg="blue"))
b1.pack()
root.mainloop()

# %% [markdown]
# Write an app that displays a window of 200 x 200 size. Now whenever the user presses ENTER key on the window the background color should become red and on pressing ESCAPE key the window should retain it’s original color

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tkinter import *
root = Tk()
root.geometry('200x200')
root.mainloop()

# %%
from tkinter import *
oldcolor=""

def enterkey(e):
    root.config(bg="red")

def escapekey(e):
    root.config(bg="SystemButtonFace")

root = Tk()
root.geometry('200x200')
b1=Button(root,text="Click Me")
root.bind("<Return>",enterkey)
root.bind("<Escape>",escapekey)
oldcolor=root["bg"]
print(oldcolor)
b1.pack()
root.mainloop()
# Out:
# SystemButtonFace

# %% [markdown]
# Write an app that displays a window of 200 x 200 size. Now whenever the user presses any key on the window the code should check whether it is “r” , “g” or “b” and change the  background color of the window accordingly

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#event handling - enter key
from tkinter import *

def clickme(e):
    f1.config(bg="red")
def clickme1(e):
    f1.config(bg="green")
def clickme2(e):
    f1.config(bg="blue")

f1 = Tk()
f1.geometry("200x200")

b1 = Button(f1, text="Enter keys - 'r', 'g, or 'b' ")
b1.pack()
f1.bind("r",clickme)
f1.bind("g",clickme1)
f1.bind("b",clickme2)

f1.mainloop()

# %%
from tkinter import *
oldcolor = ""
root = Tk()
def red_bg(e):
    root.config(bg = "red")
def green_bg(e):
    root.config(bg = "green")
def blue_bg(e):
    root.config(bg = "blue")
def escapekey(e):
    root.config(bg = oldcolor)

root.geometry("200x200")
root.bind("<r>",red_bg)
root.bind("<g>",green_bg)
root.bind("<b>",blue_bg)
root.bind("<Escape>",escapekey)
oldcolor = root["bg"]
root.mainloop()

# %%
from tkinter import *

oldcolor = ""

def r(e):
    root.config(bg="red")
    
def g(e):
    root.config(bg= "green")
    
def b(e):
    root.config(bg= "blue")
def escapekey(e):
    root.config(bg= oldcolor)
    
root = Tk()
root.geometry("200x200")
root.bind("<r>", r)
root.bind("<g>", g)
root.bind("<b>", b)
root.bind("<Escape>", escapekey)
oldcolor = root["bg"]

root.mainloop()

# %%
from tkinter import *
oldcolor=""

def pressr(e):
    root.config(bg="red")

def pressg(e):
    root.config(bg="green")
    
def pressb(e):
    root.config(bg="blue")

root = Tk()
root.geometry('200x200')
b1=Button(root,text="Click Me")
root.bind("<r>",pressr)
root.bind("<g>",pressg)
root.bind("<b>",pressb)
b1.pack()
root.mainloop()

# %%
def presskey(e):
    if e.keysym == 'r':
        root.config(bg='red')
    elif e.keysym == 'g':
        root.config(bg='green')
    elif e.keysym == 'b':
        root.config(bg='blue')
    
import tkinter
root = tkinter.Tk()
root.geometry('200x200')
root.bind('<KeyRelease>',presskey)
root.mainloop()

# %% [markdown]
# To solve the above problem , we have to do 2 things:
#
#
# Set the event handler for “<Key>” event
#
# Capture the key and check whether it is “r” , “g” or “b” and then change the background color accordingly.
#
# This can be done by using attributes of the event object passed as argument to the event handler function by Python

# %%
from tkinter import *
def changecolor(e):
    pass

root = Tk()
root.geometry('200x200')
root.bind("<Key>",changecolor)
root.mainloop()

# %%
from tkinter import *
def changecolor(e):
    ch=e.char
    if ch=="r":
        root.config(bg="red")
    elif ch=="b":
        root.config(bg="blue")
    elif ch=="g":
        root.config(bg="green")

root = Tk()
root.geometry('200x200')
root.bind("<Key>",changecolor)
root.mainloop()

# %%
from tkinter import *

root = Tk()
root.geometry('200x200')
root.bind("r",lambda e:root.config(bg="red"))
root.bind("g",lambda e:root.config(bg="green"))
root.bind("b",lambda e:root.config(bg="blue"))
root.mainloop()

# %% [markdown]
# Entry widget is the basic widget of Tkinter used to get input, i.e. text strings, from the user of an application.
#
#
# This widget allows the user to enter a single line of text.
#
#
# If the user enters a string, which is longer than the available display space of the widget, the content will be scrolled.
#
# If we want to enter multiple lines of text, we have to use the Text widget

# %%
from tkinter import *
root = Tk()
root.geometry("200x200")
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
e1 = Entry(root)
e2 = Entry(root)
l1.grid(row=0,column=0)
l2.grid(row=1,column=0)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
root.mainloop( )

# %%
a=input("enter nane")
b=input("enter last name")
a+b
# Out:
# 'sdasdsdfs'

# %% [markdown]
# The text property doesn’t work with Entry widget , so to fetch the data from Entry widget , we have 2 ways:
#
#
# Using it’s get() method
#
# OR
#
# Using Var class (StringVar, IntVar etc) objects

# %% [markdown]
# The Entry widget provides us get() method which returns contents of the widget as a string value.
#
#
# Syntax:
# var_name=<obj>.get()
#
# Example:
# s = e1.get()
#
# Assume , e1 is the object of  Entry

# %% [markdown]
# If we associate the Var objects with the Entry widget , then we can fetch the data of Entry widget by calling the get() method of these Var objects
#
# Syntax:
# var_name=<obj>.get()
#
# Example:
# s = msg.get()
#
# Assume , msg is the object of  any of the Var classes like StringVar or IntVar and is associated with Entry widget

# %% [markdown]
# Modify the previous app by adding 2 Buttons titled “Show” and “Quit”and a Label. When the user presses the first Button , the app should display firstname and lastname concatenated as a single string in the Label and when the user presses “Quit” the app should terminate

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We have 2 ways to terminate our Python app:
#
# By calling root.destroy(): The method destroy() just terminates the mainloop() and deletes all widgets
#
# By calling sys.exit(0): The function sys.exit(0) stops all active applications used by Python

# %%
#vishal
from tkinter import *
def finish():
    root.destroy()

def show():
    fname = e1.get()
    lname = e2.get()
    fullname = fname +" "+lname
    l3.config(text = fullname)

root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,width=20,anchor=W,font="Arial 10 bold")
e1 = Entry(root)
e2 = Entry(root)
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0)
l2.grid(row=1,column=0)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
l3.grid(row=2,columnspan=2,sticky=W)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %%
#vignesh
from tkinter import *
def finish():
    root.destroy()

def show():
    e1_text = e1.get()
    e2_text = e2.get()
    e3_text = e1_text + " " + e2_text
    l3['text'] = e3_text

root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,width=20,anchor=W,font="Arial 10 bold")
e1 = Entry(root)
e2 = Entry(root)
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0)
l2.grid(row=1,column=0)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
l3.grid(row=2,columnspan=2,sticky=W)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %%
#smita
from tkinter import *
def finish():
    root.destroy()
def show():
    a = str(e1.get())
    b = str(e2.get())
    e3.insert(0,a+b)
root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,width=20,anchor=W,font="Arial 10 bold")
e1 = Entry(root)
e2 = Entry(root)
e3 = Entry(root)
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0)
l2.grid(row=1,column=0)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
e3.grid(row=2, column=1)
l3.grid(row=2,columnspan=2,sticky=W)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %%
#sourav
from tkinter import *
def finish():
    root.destroy()

def show():
    l3.config(text=e1.get()+" "+e2.get())

root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,width=20,anchor=W,font="Arial 10 bold")
e1 = Entry(root)
e2 = Entry(root)
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0)
l2.grid(row=1,column=0)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
l3.grid(row=2,columnspan=2,sticky=W)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %%
from tkinter import *
def finish():
    root.destroy()

def show():
    pass

root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,width=20,anchor=W,font="Arial 10 bold")
e1 = Entry(root)
e2 = Entry(root)
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0)
l2.grid(row=1,column=0)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
l3.grid(row=2,columnspan=2,sticky=W)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %%
from tkinter import *
import sys
def finish():
    sys.exit(0) # can also be root.destroy()

def show():
    fname=e1.get()
    lname=e2.get()
    l3.config(text=fname+" "+lname)

root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,width=20,anchor=W,font="Arial 10 bold")
e1 = Entry(root)
e2 = Entry(root)
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0)
l2.grid(row=1,column=0)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
l3.grid(row=2,columnspan=2,sticky=W)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %%
from tkinter import *
import sys
def finish():
    sys.exit(0) # can also be root.destroy()

def show():
    fname=s1.get()
    lname=s2.get()
    l3.config(text=fname+" "+lname)

root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,width=20,anchor=W,font="Arial 10 bold")
s1=StringVar()
s2=StringVar()
e1 = Entry(root,textvariable=s1)
e2 = Entry(root,textvariable=s2)
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0)
l2.grid(row=1,column=0)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
l3.grid(row=2,columnspan=2,sticky=W)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %% [markdown]
# To set text in the Entry widget , we have to call the method insert( ) .
#
# Syntax:
# <obj>.insert(index,text)
#
# What is index ?
#
# index is the position in the text field where the text is to be inserted
#
# It can have any valid index starting from 0 or INSERT to indicate the current cursor pos or END to indicate end of the string

# %% [markdown]
# Example:
# e1.insert(0, "Hello")
#
# The above code will set the text “Hello” at 0th index in the Entry widget
#
# Example:
# e1.insert(END, "Hi")
#
# The above code will append the text “Hello” at the end of the current text in  the Entry widget

# %% [markdown]
# To erase text in the Entry widget , we have to call the method delete( ) .
#
# Syntax:
# <obj>.delete(first,last)
#
# first : Starting index from where deletion should begin
#
# last: Optional end index. If omitted, only a single character is removed

# %% [markdown]
# Example:
# e1.insert(0, "Bhopal")
# e1.delete(0,3)
#
# The above code will delete first 3 letters ( from index 0 to index  2) from the Entry widget.
#
# Example:
# e1.insert(0, "Bhopal")
# e1.delete(0,END)
#
# The above code will clear the entire Entry wiget

# %% [markdown]
# Modify the previous app by replacing the Label with the Entry widget as shown . The behavior of the app should remain same

# %%
from tkinter import *
import sys
def finish():
      sys.exit(0)
def show():
    pass
root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,text="You Typed")
e1 = Entry(root)
e2 = Entry(root)
e3=Entry(root)
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0,sticky=W)
l2.grid(row=1,column=0,sticky=W)
l3.grid(row=2,column=0,sticky=W)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
e3.grid(row=2,column=1)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %%
from tkinter import *
import sys

def finish():
  	sys.exit(0)
def show():
	fname=e1.get()
	lname=e2.get()
	e3.delete(0,END)
	e3.insert(0,fname+" "+lname)

root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,text="You Typed")
e1 = Entry(root)
e2 = Entry(root)
e3=Entry(root)
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0,sticky=W)
l2.grid(row=1,column=0,sticky=W)
l3.grid(row=2,column=0,sticky=W)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
e3.grid(row=2,column=1)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %% [markdown]
# Can you rewrite the previous code so that we don’t have call the delete( ) method ?

# %%
from tkinter import *
import sys

def finish():
  	sys.exit(0)
def show():
	fname=e1.get()
	lname=e2.get()
	s.set(fname+" "+lname)

root = Tk()
l1=Label(root, text="First Name")
l2=Label(root, text="Last Name")
l3=Label(root,text="You Typed")
e1 = Entry(root)
e2 = Entry(root)
s=StringVar()
e3=Entry(root,textvariable=s) 
b1=Button(root, text='Show', command=show)
b2=Button(root, text='Quit', command=finish)
l1.grid(row=0,column=0,sticky=W)
l2.grid(row=1,column=0,sticky=W)
l3.grid(row=2,column=0,sticky=W)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
e3.grid(row=2,column=1)
b1.grid(row=3, column=0, sticky=W, pady=4)
b2.grid(row=3, column=1, sticky=W, pady=4)
root.mainloop( )

# %% [markdown]
# Write a GUI app to accept 2 integers from the user and display their division. Create the GUI as shown below and make sure to handle all the exception code can throw

# %%
#smita
from tkinter import *
def divide():
    a = float(e1.get())
    b = float(e2.get())
    divide = a/b
    e3.insert(0,divide)
def clear():
    e1.delete(0, END)
    e2.delete(0, END)
    e3.delete(0, END)
def finish():
    root.destroy()
root = Tk()
root.geometry('400x200+100+200')
l1=Label(root, text="Number Division Program",font="Arial 18 bold")
l2=Label(root, text="First No:")
l3=Label(root, text="Second No:")
l4=Label(root,text="Result:")
e1=Entry(root)
e2=Entry(root)
e3=Entry(root)
b1=Button(root,text="Divide",command=divide)
b2=Button(root,text="Clear",command=clear)
b3=Button(root,text="Quit",command=finish)
l1.grid(row=0,column=0,columnspan=4)
l2.grid(row=1,column=0,sticky=E)
e1.grid(row=1,column=1)
l3.grid(row=2,column=0,sticky=E)
e2.grid(row=2,column=1)
l4.grid(row=3,column=0,sticky=E)
e3.grid(row=3,column=1)
b1.grid(row=4,column=0,pady=5,padx=5,sticky=E+W)
b2.grid(row=4,column=1,pady=5,padx=5,sticky=E+W)
b3.grid(row=4,column=2,pady=5,padx=5,sticky=E+W)
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nayak\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\nayak\AppData\Local\Temp\ipykernel_8004\751521796.py", line 4, in divide
#     a = float(e1.get())
# ValueError: could not convert string to float: 'ytr'

# %%
#demba
from tkinter import *
def divide():
    try:
        return int(e1.get()) / int(e2.get())
    except ZeroDivisionError as e:
        return e
    except Exception as e:
        return e
    
def clear():
    e1.delete(0, tk.END)
    e2.delete(0, tk.END)
    
def finish():
    root.destroy()
    
    
root = Tk()
root.geometry('400x200+100+200')
l1=Label(root, text="Number Division Program",font="Arial 18 bold")
l2=Label(root, text="First No:")
l3=Label(root, text="Second No:")
l4=Label(root,text="Result:")
e1=Entry(root)
e2=Entry(root)
e3=Entry(root)
b1=Button(root,text="Divide",command=divide)
b2=Button(root,text="Clear",command=clear)
b3=Button(root,text="Quit",command=finish)
l1.grid(row=0,column=0,columnspan=4)
l2.grid(row=1,column=0,sticky=E)
e1.grid(row=1,column=1)
l3.grid(row=2,column=0,sticky=E)
e2.grid(row=2,column=1)
l4.grid(row=3,column=0,sticky=E)
e3.grid(row=3,column=1)
b1.grid(row=4,column=0,pady=5,padx=5,sticky=E+W)
b2.grid(row=4,column=1,pady=5,padx=5,sticky=E+W)
b3.grid(row=4,column=2,pady=5,padx=5,sticky=E+W)

# %%
#sandeep
from tkinter import *
def divide():
    a=float(e1.get())
    b=float(e2.get())
    e3.insert(0,a/b)
def clear():
    pass
def finish():
    root.destroy()
root = Tk()
root.geometry('400x200+100+200')
l1=Label(root, text="Number Division Program",font="Arial 18 bold")
l2=Label(root, text="First No:")
l3=Label(root, text="Second No:")
l4=Label(root,text="Result:")
e1=Entry(root)
e2=Entry(root)
e3=Entry(root)
b1=Button(root,text="Divide",command=divide)
b2=Button(root,text="Clear",command=clear)
b3=Button(root,text="Quit",command=finish)
l1.grid(row=0,column=0,columnspan=4)
l2.grid(row=1,column=0,sticky=E)
e1.grid(row=1,column=1)
l3.grid(row=2,column=0,sticky=E)
e2.grid(row=2,column=1)
l4.grid(row=3,column=0,sticky=E)
e3.grid(row=3,column=1)
b1.grid(row=4,column=0,pady=5,padx=5,sticky=E+W)
b2.grid(row=4,column=1,pady=5,padx=5,sticky=E+W)
b3.grid(row=4,column=2,pady=5,padx=5,sticky=E+W)
root.mainloop()

# %%
#manisha
from tkinter import *

def divide():
    a=int(e1.get())
    b=int(e2.get())
    e3.insert(0,int(a/b))
    
def clear():
    pass


def finish():
    root.destroy()
    
root = Tk()
root.geometry('400x200+100+200')

l1=Label(root, text="Number Division Program",font="Arial 18 bold")
l2=Label(root, text="First No:")
l3=Label(root, text="Second No:")
l4=Label(root,text="Result:")

e1=Entry(root)
e2=Entry(root)
e3=Entry(root)

b1=Button(root,text="Divide",command=divide)
b2=Button(root,text="Clear",command=clear)
b3=Button(root,text="Quit",command=finish)

l1.grid(row=0,column=0,columnspan=4)
l2.grid(row=1,column=0,sticky=E)
e1.grid(row=1,column=1)
l3.grid(row=2,column=0,sticky=E)
e2.grid(row=2,column=1)
l4.grid(row=3,column=0,sticky=E)
e3.grid(row=3,column=1)
b1.grid(row=4,column=0,pady=5,padx=5,sticky=E+W)
b2.grid(row=4,column=1,pady=5,padx=5,sticky=E+W)
b3.grid(row=4,column=2,pady=5,padx=5,sticky=E+W)
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\nayak\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\nayak\AppData\Local\Temp\ipykernel_8004\643632232.py", line 6, in divide
#     b=int(e2.get())
# ValueError: invalid literal for int() with base 10: '345df'

# %%
from tkinter import *
def divide():
    pass
def clear():
    pass
def finish():
    pass
root = Tk()
root.geometry('400x200+100+200')
l1=Label(root, text="Number Division Program",font="Arial 18 bold")
l2=Label(root, text="First No:")
l3=Label(root, text="Second No:")
l4=Label(root,text="Result:")
e1=Entry(root)
e2=Entry(root)
e3=Entry(root)
b1=Button(root,text="Divide",command=divide)
b2=Button(root,text="Clear",command=clear)
b3=Button(root,text="Quit",command=finish)
l1.grid(row=0,column=0,columnspan=4)
l2.grid(row=1,column=0,sticky=E)
e1.grid(row=1,column=1)
l3.grid(row=2,column=0,sticky=E)
e2.grid(row=2,column=1)
l4.grid(row=3,column=0,sticky=E)
e3.grid(row=3,column=1)
b1.grid(row=4,column=0,pady=5,padx=5,sticky=E+W)
b2.grid(row=4,column=1,pady=5,padx=5,sticky=E+W)
b3.grid(row=4,column=2,pady=5,padx=5,sticky=E+W)
root.mainloop()

# %%
root = Tk()
root.geometry('400x200+100+200')
l1=Label(root, text="Number Division Program",font="Arial 18 bold")
l2=Label(root, text="First No:")
l3=Label(root, text="Second No:")
l4=Label(root,text="Result:")
e1=Entry(root)
e2=Entry(root)
e3=Entry(root)
b1=Button(root,text="Divide",command=divide)
b2=Button(root,text="Clear",command=clear)
b3=Button(root,text="Quit",command=finish)
l1.grid(row=0,column=0,columnspan=4)
l2.grid(row=1,column=0,sticky=E)
e1.grid(row=1,column=1)
l3.grid(row=2,column=0,sticky=E)
e2.grid(row=2,column=1)
l4.grid(row=3,column=0,sticky=E)
e3.grid(row=3,column=1)
b1.grid(row=4,column=0,pady=5,padx=5,sticky=E+W)
b2.grid(row=4,column=1,pady=5,padx=5,sticky=E+W)
b3.grid(row=4,column=2,pady=5,padx=5,sticky=E+W)
root.mainloop()

# %%
from tkinter import *
def divide():
    try:
        e3.delete(0, END)
        e3.config(fg="red")
        a=int(e1.get())
        b=int(e2.get())
        c=a/b
        e3.config(fg="green")
        e3.insert(0,str(c))
    except ZeroDivisionError:
        e3.insert(0,"Divide by 0!")
    except ValueError:
        e3.insert(0,"Only digits allowed!")

def clear():
    e1.delete(0, END)
    e2.delete(0, END)
    e3.delete(0, END)
    e3.focus()

def finish():
    root.destroy()

root = Tk()
root.geometry('400x200+100+200')
l1=Label(root, text="Number Division Program",font="Arial 18 bold")
l2=Label(root, text="First No:")
l3=Label(root, text="Second No:")
l4=Label(root,text="Result:")
e1=Entry(root)
e2=Entry(root)
e3=Entry(root)
b1=Button(root,text="Divide",command=divide)
b2=Button(root,text="Clear",command=clear)
b3=Button(root,text="Quit",command=finish)
l1.grid(row=0,column=0,columnspan=4)
l2.grid(row=1,column=0,sticky=E)
e1.grid(row=1,column=1)
l3.grid(row=2,column=0,sticky=E)
e2.grid(row=2,column=1)
l4.grid(row=3,column=0,sticky=E)
e3.grid(row=3,column=1)
b1.grid(row=4,column=0,pady=5,padx=5,sticky=E+W)
b2.grid(row=4,column=1,pady=5,padx=5,sticky=E+W)
b3.grid(row=4,column=2,pady=5,padx=5,sticky=E+W)
root.mainloop()

# %%
root = Tk()
root.geometry('400x200+100+200')
l1=Label(root, text="Number Division Program",font="Arial 18 bold")
l2=Label(root, text="First No:")
l3=Label(root, text="Second No:")
l4=Label(root,text="Result:")
e1=Entry(root)
e2=Entry(root)
e3=Entry(root)
b1=Button(root,text="Divide",command=divide)
b2=Button(root,text="Clear",command=clear)
b3=Button(root,text="Quit",command=finish)
l1.grid(row=0,column=0,columnspan=4)
l2.grid(row=1,column=0,sticky=E)
e1.grid(row=1,column=1)
l3.grid(row=2,column=0,sticky=E)
e2.grid(row=2,column=1)
l4.grid(row=3,column=0,sticky=E)
e3.grid(row=3,column=1)
b1.grid(row=4,column=0,pady=5,padx=5,sticky=E+W)
b2.grid(row=4,column=1,pady=5,padx=5,sticky=E+W)
b3.grid(row=4,column=2,pady=5,padx=5,sticky=E+W)
root.mainloop()

# %% [markdown]
# Rewrite the same app using Var classes

# %%
from tkinter import *
def divide():
    try:
        c.set("")
        e3.config(fg="red")
        c.set(a.get()/b.get())
        e3.config(fg="green")
    except ZeroDivisionError:
        c.set("Divide by 0")
    except ValueError:
        c.set("Only digits allowed!")
    
def clear():
    a.set("")
    b.set("")
    c.set("")
    e1.focus()
def finish():
    root.destroy()

# %%
root = Tk()
root.geometry('400x200+100+200')
a=IntVar()
b=IntVar()
c=IntVar()
a.set("")
b.set("")
c.set("")
l1=Label(root, text="Number Division Program",font="Arial 18 bold")
l2=Label(root, text="First No:")
l3=Label(root, text="Second No:")
l4=Label(root,text="Result:")
e1=Entry(root,textvariable=a)
e2=Entry(root,textvariable=b)
e3=Entry(root,textvariable=c)
b1=Button(root,text="Divide",command=divide)
b2=Button(root,text="Clear",command=clear)
b3=Button(root,text="Quit",command=finish)
l1.grid(row=0,column=0,columnspan=4)
l2.grid(row=1,column=0,sticky=E)
e1.grid(row=1,column=1)
l3.grid(row=2,column=0,sticky=E)
e2.grid(row=2,column=1)
l4.grid(row=3,column=0,sticky=E)
e3.grid(row=3,column=1)
b1.grid(row=4,column=0,pady=5,padx=5,sticky=E+W)
b2.grid(row=4,column=1,pady=5,padx=5,sticky=E+W)
b3.grid(row=4,column=2,pady=5,padx=5,sticky=E+W)
root.mainloop()
