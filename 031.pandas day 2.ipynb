# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df[0]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age' , 'GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('NBA.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FA55-E833
#
#  Directory of C:\Users\win10\jupyter\Complete Python Module-20210227T092441Z-001\Complete Python Module\16-17. Pandas-Numpy
#
# 02/27/2022  10:44 AM    <DIR>          .
# 02/27/2022  10:44 AM    <DIR>          ..
# 02/27/2022  10:25 AM    <DIR>          .ipynb_checkpoints
# 07/07/2021  08:04 PM           107,005 16.1 Pandas file read and write operation.ipynb
# 06/01/2021  06:38 AM           138,431 16.2 Pandas data manipulation .ipynb
# 06/01/2021  06:38 AM           105,034 16.3 Pandas data manipulation_continue .ipynb
# 07/07/2021  08:04 PM            94,904 17. Numpy in details.ipynb
# 02/26/2022  12:05 PM             1,173 addresses.csv
# 02/26/2022  12:05 PM             1,589 contacts.csv
# 04/11/2021  06:07 AM    <DIR>          example_files
# 02/26/2022  12:05 PM               277 holiday_schedules.csv
# 02/26/2022  12:05 PM            18,015 locations.csv
# 02/26/2022  01:00 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 02/26/2022  01:00 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 02/26/2022  01:00 PM            71,993 LUSID Excel - Manage Orders.xlsx
# 02/26/2022  01:00 PM           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 02/26/2022  01:00 PM           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 02/26/2022  01:00 PM           136,632 LUSID Excel - Setting up your market data.xlsx
# 02/26/2022  12:05 PM             1,610 mail_addresses.csv
# 08/07/2020  11:06 PM                 0 my_database4.db
# 08/07/2020  11:07 PM             8,192 my_database5.db
# 08/08/2020  03:48 AM           189,104 mydata.h5
# 08/07/2020  11:06 PM             8,192 mydata2.sqlite
# 02/27/2022  10:44 AM            81,551 NBA.csv
# 11/06/2021  09:38 PM            39,413 Numpy.ipynb
# 02/26/2022  12:05 PM             2,281 organizations.csv
# 02/26/2022  01:04 PM           263,960 pandas data manupulation.ipynb
# 02/27/2022  10:43 AM            29,296 pandas day 2.ipynb
# 02/26/2022  01:51 PM           289,880 Pandas.ipynb
# 02/26/2022  12:05 PM             2,092 phones.csv
# 02/26/2022  12:05 PM                60 programs.csv
# 02/26/2022  12:05 PM               350 regular_schedules.csv
# 02/26/2022  12:31 PM               254 sample_test.csv
# 02/26/2022  12:05 PM            19,128 services.csv
# 02/26/2022  12:17 PM            14,578 taxonomy.csv
# 11/06/2021  10:19 PM             5,122 Untitled1.ipynb
#               32 File(s)      2,274,943 bytes
#                4 Dir(s)  470,429,057,024 bytes free

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 3

# %%
l[0].to_csv('cricket.csv' , index = False )

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Dharamsala, 3rd T20I, Feb...
# 2  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
# 3  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...

# %%
l[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# 1    0  0  0   0   0
# 2    -  -  -   -   -
# 3    0  0  0  14   1
# 4    -  -  -   -   -
# ..  .. .. ..  ..  ..
# 92   0  0  0   0   0
# 93   0  0  3   4   3
# 94   0  4  1  32  20
# 95   0  0  0   0   0
# 96   0  8  1  77  74
#
# [97 rows x 15 columns]

# %%
d ="""{"name" : "Hari Sankar Nayak" , 
"email id " : "hh@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result  = json.loads(d)

# %%
result
# Out:
# {'name': 'Hari Sankar Nayak',
#  'email id ': 'hh@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
result['name']
# Out:
# 'Hari Sankar Nayak'

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
pd.DataFrame(result)
# Out:
#                 name     email id  tech   plateform
# 0  Hari Sankar Nayak  hh@gmail.com   ML  techneuron
# 1  Hari Sankar Nayak  hh@gmail.com   DL  kidsneuron
# 2  Hari Sankar Nayak  hh@gmail.com   CV     ineuron

# %%
result['tech']
# Out:
# ['ML', 'DL', 'CV']

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d)
# Out:
#                          packetType  \
# checkEngineLightFlag              D
# batteryVoltageStableTime          D
# batteryVoltageStable              D
# batteryVoltageOff                 D
# batteryCrankParamTN               D
# batteryCrankParamVN               D
# batteryCrankParamTP               D
# batteryCrankParamVP               D
# batteryCrankParamTT               D
# batteryCrankParamV0               D
# batteryVoltageMaxOn               D
# batteryVoltageMinOn               D
# batteryVoltageMaxOff              D
# batteryVoltageMinOff              D
# batteryVoltageOnAverage           D
# engineLoadMax                     D
# engineLoadAverage                 D
# rpmMax                            D
# rpmAverage                        D
# gpsSpeedAverage                   D
# vssMax                            D
# vssAverage                        D
# tcuTemperatureMin                 D
# tcuTemperatureMax                 D
# tcuTemperatureAverage             D
# coolantMin                        D
# coolantMax                        D
# coolantAverage                    D
# packetStartLocal                  D
# tripStartLocal                    D
# milIndicator                      D
# monitorsNotReady                  D
# imei                              D
# gatewayTs                         D
# diagnosticPidData                 D
# iwrapVer                          D
# sourceSystem                      D
# configVer                         D
# oemName                           D
# unitType                          D
# cpVer                             D
# igpsVer                           D
# messageType                       D
# pomVer                            D
# headerVer                         D
# timestamp                         D
# deviceType                        D
# visorVer                          D
# transactionId                     D
# deviceSerialNo                    D
# subOrganization                   D
# organization                      D
# operation                         D
#
#                                                                        data  \
# checkEngineLightFlag                                                      F
# batteryVoltageStableTime                                                  0
# batteryVoltageStable                                                      0
# batteryVoltageOff                                                     12.42
# batteryCrankParamTN                                                   -0.08
# batteryCrankParamVN                                                    0.00
# batteryCrankParamTP                                                   -0.08
# batteryCrankParamVP                                                    0.00
# batteryCrankParamTT                                                -0.00008
# batteryCrankParamV0                                                    0.00
# batteryVoltageMaxOn                                                   13.05
# batteryVoltageMinOn                                                   12.97
# batteryVoltageMaxOff                                                  12.46
# batteryVoltageMinOff                                                  12.36
# batteryVoltageOnAverage                                               13.02
# engineLoadMax                                                            84
# engineLoadAverage                                                     39.98
# rpmMax                                                                 3487
# rpmAverage                                                          1431.29
# gpsSpeedAverage                                                       21.99
# vssMax                                                                53.44
# vssAverage                                                            23.06
# tcuTemperatureMin                                                     82.40
# tcuTemperatureMax                                                    109.40
# tcuTemperatureAverage                                                104.87
# coolantMin                                                           158.00
# coolantMax                                                           188.60
# coolantAverage                                                       180.20
# packetStartLocal                                              1508143346000
# tripStartLocal                                                1508143346000
# milIndicator                                                              F
# monitorsNotReady                                                          0
# imei                                                               60DF5417
# gatewayTs                                                     1515613306592
# diagnosticPidData         [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                NaN
# sourceSystem                                                            NaN
# configVer                                                               NaN
# oemName                                                                 NaN
# unitType                                                                NaN
# cpVer                                                                   NaN
# igpsVer                                                                 NaN
# messageType                                                             NaN
# pomVer                                                                  NaN
# headerVer                                                               NaN
# timestamp                                                               NaN
# deviceType                                                              NaN
# visorVer                                                                NaN
# transactionId                                                           NaN
# deviceSerialNo                                                          NaN
# subOrganization                                                         NaN
# organization                                                            NaN
# operation                                                               NaN
#
#                                                         header
# checkEngineLightFlag                                       NaN
# batteryVoltageStableTime                                   NaN
# batteryVoltageStable                                       NaN
# batteryVoltageOff                                          NaN
# batteryCrankParamTN                                        NaN
# batteryCrankParamVN                                        NaN
# batteryCrankParamTP                                        NaN
# batteryCrankParamVP                                        NaN
# batteryCrankParamTT                                        NaN
# batteryCrankParamV0                                        NaN
# batteryVoltageMaxOn                                        NaN
# batteryVoltageMinOn                                        NaN
# batteryVoltageMaxOff                                       NaN
# batteryVoltageMinOff                                       NaN
# batteryVoltageOnAverage                                    NaN
# engineLoadMax                                              NaN
# engineLoadAverage                                          NaN
# rpmMax                                                     NaN
# rpmAverage                                                 NaN
# gpsSpeedAverage                                            NaN
# vssMax                                                     NaN
# vssAverage                                                 NaN
# tcuTemperatureMin                                          NaN
# tcuTemperatureMax                                          NaN
# tcuTemperatureAverage                                      NaN
# coolantMin                                                 NaN
# coolantMax                                                 NaN
# coolantAverage                                             NaN
# packetStartLocal                                           NaN
# tripStartLocal                                             NaN
# milIndicator                                               NaN
# monitorsNotReady                                           NaN
# imei                                                  60DF5417
# gatewayTs                                                  NaN
# diagnosticPidData                                          NaN
# iwrapVer                                                1.9.20
# sourceSystem                                               CDP
# configVer                                                  1.1
# oemName                                                    HUM
# unitType                                                     0
# cpVer                                                 7.50.1.9
# igpsVer                                                  1.3.7
# messageType                                       Notification
# pomVer                                                     1.0
# headerVer                                                   V6
# timestamp                                                    0
# deviceType                                             InDrive
# visorVer                                                1.4.35
# transactionId             53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                        60DF5417
# subOrganization                                            HUM
# organization                                               HUM
# operation                                         Notification

# %%
d1 = d["data"]

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d1)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/47077  1243492669
# 1     https://github.com/pandas-dev/pandas/pull/47076  1243412992
# 2     https://github.com/pandas-dev/pandas/pull/47075  1243374107
# 3     https://github.com/pandas-dev/pandas/pull/47074  1243359572
# 4   https://github.com/pandas-dev/pandas/issues/47073  1243086499
# 5     https://github.com/pandas-dev/pandas/pull/47072  1242986429
# 6   https://github.com/pandas-dev/pandas/issues/47071  1242983125
# 7     https://github.com/pandas-dev/pandas/pull/47070  1242852588
# 8     https://github.com/pandas-dev/pandas/pull/47066  1242351460
# 9     https://github.com/pandas-dev/pandas/pull/47064  1242299667
# 10    https://github.com/pandas-dev/pandas/pull/47061  1241932207
# 11  https://github.com/pandas-dev/pandas/issues/47058  1240509942
# 12  https://github.com/pandas-dev/pandas/issues/47055  1239889808
# 13    https://github.com/pandas-dev/pandas/pull/47051  1239370132
# 14    https://github.com/pandas-dev/pandas/pull/47047  1239280693
# 15    https://github.com/pandas-dev/pandas/pull/47046  1239268332
# 16    https://github.com/pandas-dev/pandas/pull/47045  1239229786
# 17  https://github.com/pandas-dev/pandas/issues/47043  1239165130
# 18  https://github.com/pandas-dev/pandas/issues/47042  1239027357
# 19  https://github.com/pandas-dev/pandas/issues/47041  1238866442
# 20  https://github.com/pandas-dev/pandas/issues/47039  1238206645
# 21    https://github.com/pandas-dev/pandas/pull/47037  1237936691
# 22    https://github.com/pandas-dev/pandas/pull/47035  1237645741
# 23    https://github.com/pandas-dev/pandas/pull/47034  1237572612
# 24    https://github.com/pandas-dev/pandas/pull/47032  1236352230
# 25  https://github.com/pandas-dev/pandas/issues/47030  1236274176
# 26    https://github.com/pandas-dev/pandas/pull/47028  1236240934
# 27  https://github.com/pandas-dev/pandas/issues/47024  1236021807
# 28    https://github.com/pandas-dev/pandas/pull/47018  1235700810
# 29  https://github.com/pandas-dev/pandas/issues/47014  1235440194
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD844NWiF   47077
# 1   PR_kwDOAA0YD844NFgU   47076
# 2   PR_kwDOAA0YD844M9UV   47075
# 3   PR_kwDOAA0YD844M6QM   47074
# 4    I_kwDOAA0YD85KF_6j   47073
# 5   PR_kwDOAA0YD844Lq9z   47072
# 6    I_kwDOAA0YD85KFmrV   47071
# 7   PR_kwDOAA0YD844LOHh   47070
# 8   PR_kwDOAA0YD844JmWH   47066
# 9   PR_kwDOAA0YD844JbFT   47064
# 10  PR_kwDOAA0YD844IOcl   47061
# 11   I_kwDOAA0YD85J8K32   47058
# 12   I_kwDOAA0YD85J5zeQ   47055
# 13  PR_kwDOAA0YD843_vLs   47051
# 14  PR_kwDOAA0YD843_ctg   47047
# 15  PR_kwDOAA0YD843_aGo   47046
# 16  PR_kwDOAA0YD843_Rzh   47045
# 17   I_kwDOAA0YD85J3CjK   47043
# 18   I_kwDOAA0YD85J2g6d   47042
# 19   I_kwDOAA0YD85J15oK   47041
# 20   I_kwDOAA0YD85JzYi1   47039
# 21  PR_kwDOAA0YD84367xP   47037
# 22  PR_kwDOAA0YD84357VG   47035
# 23  PR_kwDOAA0YD8435rMH   47034
# 24  PR_kwDOAA0YD8431mtS   47032
# 25   I_kwDOAA0YD85JsAwA   47030
# 26  PR_kwDOAA0YD8431R2u   47028
# 27   I_kwDOAA0YD85JrDIv   47024
# 28  PR_kwDOAA0YD843zvr_   47018
# 29   I_kwDOAA0YD85Jo1JC   47014
#
#                                                 title  ... closed_at  \
# 0   REF: Manager.fast_xs to return SingleBlockMana...  ...       NaT
# 1                    ENH: liboffsets support non-nano  ...       NaT
# 2         CI: mypy&pyright in manual pre-commit stage  ...       NaT
# 3   REF: Add Manager.column_setitem to set values ...  ...       NaT
# 4   BUG: read_csv raises on bad line when should s...  ...       NaT
# 5   Backport PR #47059 on branch 1.4.x (REGR: Styl...  ...       NaT
# 6                         BUG: Reset index regression  ...       NaT
# 7   TST: add copy/view test for setting columns wi...  ...       NaT
# 8          TYP: resolve mypy ignores in core/apply.py  ...       NaT
# 9    TYP: resolve mypy ignores in core/groupby/ops.py  ...       NaT
# 10                        DOC: Improve reshape\concat  ...       NaT
# 11  DOC: Improve documentation for mode parameter ...  ...       NaT
# 12  BUG: Reindexing `pd.Float64Dtype()` series giv...  ...       NaT
# 13  BUG: `DataFrame.shift` shows different behavio...  ...       NaT
# 14  ENH: move DataError from core/base.py to error...  ...       NaT
# 15  Update mangle_dupe_cols documentation to refle...  ...       NaT
# 16                 TYP: Mypy workaround for NoDefault  ...       NaT
# 17    API: DatetimeIndex.get_loc(date) partial-slice?  ...       NaT
# 18           DOC: `ddof` in `cov` when `nan`s present  ...       NaT
# 19  BUG: ValueError: Unknown subheader signature i...  ...       NaT
# 20  BUG: `DataFrame.shift` shows different behavio...  ...       NaT
# 21                               TYP: pandas/_testing  ...       NaT
# 22                 Stacklevel argument updated #46687  ...       NaT
# 23  ENH: Incorproate ArrowDtype into ArrowExtensio...  ...       NaT
# 24                   CI: Start Testing on Python 3.11  ...       NaT
# 25                       DOC: DataFrame.rename Method  ...       NaT
# 26  Fix: Pandas rolling removes imaginary part of ...  ...       NaT
# 27               BUG: read_csv not guessing delimiter  ...       NaT
# 28  REF: merge datetime_to_datetime64 into array_t...  ...       NaT
# 29       ENH: implement DateOffset + datetime64 array  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0              MEMBER                NaN    0.0
# 1              MEMBER                NaN    0.0
# 2         CONTRIBUTOR                NaN    1.0
# 3              MEMBER                NaN    0.0
# 4                NONE                NaN    NaN
# 5              MEMBER                NaN    0.0
# 6         CONTRIBUTOR                NaN    NaN
# 7              MEMBER                NaN    0.0
# 8         CONTRIBUTOR                NaN    0.0
# 9         CONTRIBUTOR                NaN    0.0
# 10               NONE                NaN    0.0
# 11               NONE                NaN    NaN
# 12               NONE                NaN    NaN
# 13        CONTRIBUTOR                NaN    0.0
# 14        CONTRIBUTOR                NaN    0.0
# 15               NONE                NaN    0.0
# 16        CONTRIBUTOR                NaN    0.0
# 17             MEMBER                NaN    NaN
# 18        CONTRIBUTOR                NaN    NaN
# 19               NONE                NaN    NaN
# 20        CONTRIBUTOR                NaN    NaN
# 21        CONTRIBUTOR                NaN    1.0
# 22        CONTRIBUTOR                NaN    0.0
# 23             MEMBER                NaN    0.0
# 24             MEMBER                NaN    1.0
# 25               NONE                NaN    NaN
# 26        CONTRIBUTOR                NaN    0.0
# 27               NONE                NaN    NaN
# 28             MEMBER                NaN    0.0
# 29               NONE                NaN    NaN
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
#                                                  body  \
# 0   This is something that I encountered in https:...
# 1   - [ ] closes #xxxx (Replace xxxx with the Gith...
# 2   xref https://github.com/pandas-dev/pandas/pull...
# 3   The `column_setitem` is a method I was adding ...
# 4   ### Pandas version checks\n\n- [X] I have chec...
# 5   Backport PR #47059\r\n\r\nrelease note already...
# 6   ### Pandas version checks\n\n- [X] I have chec...
# 7   Similarly as https://github.com/pandas-dev/pan...
# 8   xref https://github.com/pandas-dev/pandas/issu...
# 9   xref https://github.com/pandas-dev/pandas/issu...
# 10  - [x] closes #46825\r\n- [x] All [code checks ...
# 11  ### Pandas version checks\n\n- [X] I have chec...
# 12  ### Pandas version checks\r\n\r\n- [X] I have ...
# 13  - [x] closes #47039 \r\n- [x] [Tests added and...
# 14  - [x] xref #27656. I think it might be best to...
# 15  - [ ] [Tests added and passed](https://pandas....
# 16  This uses the mypy-workaround from https://git...
# 17  ATM if we pass an stdlib date object, it gets ...
# 18  ### Pandas version checks\n\n- [X] I have chec...
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  ### Pandas version checks\r\n\r\n- [X] I have ...
# 21  Toward's pyrights reportGeneralTypeIssues. Aft...
# 22  - [x] closes #46687 \r\n- [ ] [Tests added and...
# 23  - [x] [Tests added and passed](https://pandas....
# 24  - [ ] xref #46680 (Replace xxxx with the Githu...
# 25  ### Pandas version checks\n\n- [x] I have chec...
# 26  - [ ] closes #46619\r\n- [ ] [Tests added and ...
# 27  ### Pandas version checks\n\n- [X] I have chec...
# 28  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 29  #### Is your feature request related to a prob...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47077',
#   'id': 1243492669,
#   'node_id': 'PR_kwDOAA0YD844NWiF',
#   'number': 47077,
#   'title': 'REF: Manager.fast_xs to return SingleBlockManager instead of array',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Related to non-user accessible pandas implementation'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 85,
#    'closed_issues': 781,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-05-20T18:34:43Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-05-20T18:34:43Z',
#   'updated_at': '2022-05-20T18:34:47Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47077',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47077',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47077.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47077.patch',
#    'merged_at': None},
#   'body': 'This is something that I encountered in https://github.com/pandas-dev/pandas/pull/46958, but again something that can be broken off / potentially useful anyway. \r\n\r\nCurrently the `fast_xs` method returns an array, but the only two places where it is being used (`xs` / `_ixs`), this array is directly wrapped in a Series. So by letting ``fast_xs`` return a manager instead, this gives a slight simplification / faster series construction.\r\n\r\nThe reason that it is also useful for https://github.com/pandas-dev/pandas/pull/46958 is because the CoW is handled at the manager level, so when creating a subset of a DataFrame (here in `xs`), ideally that is done by creating a subset manager (with proper references if needed) instead of going through raw arrays (as how it is done for example when accessing a column as a Series).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47076',
#   'id': 1243412992,
#   'node_id': 'PR_kwDOAA0YD844NFgU',
#   'number': 47076,
#   'title': 'ENH: liboffsets support non-nano',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-20T17:04:10Z',
#   'updated_at': '2022-05-20T17:04:10Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47076',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47076',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47076.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47076.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47075',
#   'id': 1243374107,
#   'node_id': 'PR_kwDOAA0YD844M9UV',
#   'number': 47075,
#   'title': 'CI: mypy&pyright in manual pre-commit stage',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-20T16:20:41Z',
#   'updated_at': '2022-05-20T19:31:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47075',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47075',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47075.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47075.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/pull/47067#discussion_r877610624',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47074',
#   'id': 1243359572,
#   'node_id': 'PR_kwDOAA0YD844M6QM',
#   'number': 47074,
#   'title': 'REF: Add Manager.column_setitem to set values into a single column (without intermediate series)',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Related to non-user accessible pandas implementation'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-20T16:04:53Z',
#   'updated_at': '2022-05-20T17:40:45Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47074',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47074',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47074.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47074.patch',
#    'merged_at': None},
#   'body': 'The `column_setitem` is a method I was adding in https://github.com/pandas-dev/pandas/pull/46958, is something that can be broken off from that PR, and is IMO also a generally useful change.\r\n\r\nCurrently in some cases to set values into a single column (eg `df.loc[idx, "A"] = value`), we create an intermediate Series for that column, set values into that Series, and then update the DataFrame from that updated Series. I think it would be generally good to avoid creating this intermediate Series, and moving the actual/final "set" operation to the internals (as is done for other set operations).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47073',
#   'id': 1243086499,
#   'node_id': 'I_kwDOAA0YD85KF_6j',
#   'number': 47073,
#   'title': 'BUG: read_csv raises on bad line when should skip or warn',
#   'user': {'login': 'arekkulczycki',
#    'id': 36327192,
#    'node_id': 'MDQ6VXNlcjM2MzI3MTky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36327192?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arekkulczycki',
#    'html_url': 'https://github.com/arekkulczycki',
#    'followers_url': 'https://api.github.com/users/arekkulczycki/followers',
#    'following_url': 'https://api.github.com/users/arekkulczycki/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arekkulczycki/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/arekkulczycki/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arekkulczycki/subscriptions',
#    'organizations_url': 'https://api.github.com/users/arekkulczycki/orgs',
#    'repos_url': 'https://api.github.com/users/arekkulczycki/repos',
#    'events_url': 'https://api.github.com/users/arekkulczycki/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/arekkulczycki/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-20T12:33:54Z',
#   'updated_at': '2022-05-20T12:59:22Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nfrom io import StringIO\r\n\r\ncsv = \'col1,col2\\n""malformed","quotes"",\'\r\nio = StringIO(csv)\r\n\r\npd.read_csv(io, on_bad_lines="skip")  # or alternatively "warn"\r\n\r\n# ParserError: Error tokenizing data. C error: EOF inside string starting at row 1\n```\n\n\n### Issue Description\n\nThe combination of \r\n\r\n- malformed text with quotes and a delimiter hidden in between\r\n- doublequote=True\r\n- on_bad_lines="skip"\r\n\r\nraises a ParserError instead of skipping the malformed row.\n\n### Expected Behavior\n\nThe reader skips the malformed row and reads the csv successfully.\n\n### Installed Versions\n\n<details>\r\n\r\ncommit : https://github.com/pandas-dev/pandas/commit/4bfe3d07b4858144c219b9346329027024102ab6\r\npython : 3.8.10.final.0\r\npython-bits : 64\r\nOS : Linux\r\nOS-release : 5.4.0-89-generic\r\nVersion : https://github.com/pandas-dev/pandas/issues/100-Ubuntu SMP Fri Sep 24 14:50:10 UTC 2021\r\nmachine : x86_64\r\nprocessor : x86_64\r\nbyteorder : little\r\nLC_ALL : None\r\nLANG : pl_PL.UTF-8\r\nLOCALE : pl_PL.UTF-8\r\n\r\npandas : 1.4.2\r\nnumpy : 1.22.3\r\npytz : 2022.1\r\ndateutil : 2.8.2\r\npip : 20.0.2\r\nsetuptools : 45.2.0\r\nCython : None\r\npytest : None\r\nhypothesis : None\r\nsphinx : None\r\nblosc : None\r\nfeather : None\r\nxlsxwriter : None\r\nlxml.etree : None\r\nhtml5lib : None\r\npymysql : None\r\npsycopg2 : None\r\njinja2 : None\r\nIPython : 8.3.0\r\npandas_datareader: None\r\nbs4 : 4.8.2\r\nbottleneck : None\r\nbrotli : None\r\nfastparquet : None\r\nfsspec : None\r\ngcsfs : None\r\nmarkupsafe : 1.1.0\r\nmatplotlib : None\r\nnumba : None\r\nnumexpr : None\r\nodfpy : None\r\nopenpyxl : None\r\npandas_gbq : None\r\npyarrow : None\r\npyreadstat : None\r\npyxlsb : None\r\ns3fs : None\r\nscipy : None\r\nsnappy : None\r\nsqlalchemy : None\r\ntables : None\r\ntabulate : None\r\nxarray : None\r\nxlrd : None\r\nxlwt : None\r\nzstandard : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47072',
#   'id': 1242986429,
#   'node_id': 'PR_kwDOAA0YD844Lq9z',
#   'number': 47072,
#   'title': 'Backport PR #47059 on branch 1.4.x (REGR: Styler buf and encoding in to_latex and to_html)',
#   'user': {'login': 'simonjayhawkins',
#    'id': 13159005,
#    'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simonjayhawkins',
#    'html_url': 'https://github.com/simonjayhawkins',
#    'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#    'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#    'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#    'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#    'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 57395487,
#     'node_id': 'MDU6TGFiZWw1NzM5NTQ4Nw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20HTML',
#     'name': 'IO HTML',
#     'color': '006b75',
#     'default': False,
#     'description': 'read_html, to_html, Styler.apply, Styler.applymap'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/95',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95/labels',
#    'id': 7829734,
#    'node_id': 'MI_kwDOAA0YD84Ad3jm',
#    'number': 95,
#    'title': '1.4.3',
#    'description': 'on-merge: backport to 1.4.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 31,
#    'closed_issues': 52,
#    'state': 'open',
#    'created_at': '2022-04-01T18:18:24Z',
#    'updated_at': '2022-05-20T11:53:29Z',
#    'due_on': '2022-04-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2022-05-20T11:02:17Z',
#   'updated_at': '2022-05-20T17:33:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47072',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47072',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47072.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47072.patch',
#    'merged_at': None},
#   'body': 'Backport PR #47059\r\n\r\nrelease note already backported in #47062',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47071',
#   'id': 1242983125,
#   'node_id': 'I_kwDOAA0YD85KFmrV',
#   'number': 47071,
#   'title': 'BUG: Reset index regression',
#   'user': {'login': 'znicholls',
#    'id': 23625371,
#    'node_id': 'MDQ6VXNlcjIzNjI1Mzcx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23625371?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/znicholls',
#    'html_url': 'https://github.com/znicholls',
#    'followers_url': 'https://api.github.com/users/znicholls/followers',
#    'following_url': 'https://api.github.com/users/znicholls/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/znicholls/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/znicholls/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/znicholls/subscriptions',
#    'organizations_url': 'https://api.github.com/users/znicholls/orgs',
#    'repos_url': 'https://api.github.com/users/znicholls/repos',
#    'events_url': 'https://api.github.com/users/znicholls/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/znicholls/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False,
#     'description': 'pandas objects compatability with Numpy or Python functions'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/95',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95/labels',
#    'id': 7829734,
#    'node_id': 'MI_kwDOAA0YD84Ad3jm',
#    'number': 95,
#    'title': '1.4.3',
#    'description': 'on-merge: backport to 1.4.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 31,
#    'closed_issues': 52,
#    'state': 'open',
#    'created_at': '2022-04-01T18:18:24Z',
#    'updated_at': '2022-05-20T11:53:29Z',
#    'due_on': '2022-04-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-05-20T10:59:01Z',
#   'updated_at': '2022-05-20T11:53:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nfrom pandas import DataFrame, Index\r\nimport xarray\r\n\r\ndf = DataFrame(\r\n    [[1, 2], [3, 4]],\r\n    columns=xarray.cftime_range("0001", periods=2),\r\n    index=Index(["hi", "bye"], name="string"),\r\n)\r\n# currently fails with TypeError\r\nres = df.reset_index()\n```\n\n\n### Issue Description\n\nThe above leads to a type error.\n\n### Expected Behavior\n\nReset index. I would guess that the columns should be downcast from `CFTimeIndex` to `Index` with object type but maybe there\'s a better option.\n\n### Installed Versions\n\n<details>\r\n\r\nminiconda3/envs/pandas-dev/lib/python3.8/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 1def8d9f3f0690ae93cbf611246f80f79a0faeaa\r\npython           : 3.8.13.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 19.6.0\r\nVersion          : Darwin Kernel Version 19.6.0: Mon Apr 18 21:50:40 PDT 2022; root:xnu-6153.141.62~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_AU.UTF-8\r\nLOCALE           : en_AU.UTF-8\r\n\r\npandas           : 1.5.0.dev0+798.g1def8d9f3f\r\nnumpy            : 1.22.3\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\npip              : 22.0.4\r\nsetuptools       : 62.3.2\r\nCython           : 0.29.30\r\npytest           : 7.1.2\r\nhypothesis       : 6.46.7\r\nsphinx           : 4.5.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : 4.8.0\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.3\r\nIPython          : 8.3.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : 1.3.4\r\nbrotli           : \r\nfastparquet      : 0.8.1\r\nfsspec           : 2021.11.0\r\ngcsfs            : 2021.11.0\r\nmatplotlib       : 3.5.2\r\nnumba            : 0.53.1\r\nnumexpr          : 2.8.0\r\nodfpy            : None\r\nopenpyxl         : 3.0.9\r\npandas_gbq       : None\r\npyarrow          : 8.0.0\r\npyreadstat       : 1.1.6\r\npyxlsb           : None\r\ns3fs             : 2021.11.0\r\nscipy            : 1.8.0\r\nsnappy           : \r\nsqlalchemy       : 1.4.36\r\ntables           : 3.7.0\r\ntabulate         : 0.8.9\r\nxarray           : 2022.3.0\r\nxlrd             : 2.0.1\r\nxlwt             : 1.3.0\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47070',
#   'id': 1242852588,
#   'node_id': 'PR_kwDOAA0YD844LOHh',
#   'number': 47070,
#   'title': 'TST: add copy/view test for setting columns with an array/series',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 85,
#    'closed_issues': 781,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-05-20T18:34:43Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-05-20T09:06:10Z',
#   'updated_at': '2022-05-20T14:40:47Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47070',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47070',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47070.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47070.patch',
#    'merged_at': None},
#   'body': 'Similarly as https://github.com/pandas-dev/pandas/pull/46979, this is adding some test cases explicitly testing copy/view behaviour for a specific topic: if we set an array or series as a column, is the new column a copy or a view of the original data? \r\nAt this moment, we actually already do make a copy of that data (with one exception being the cached RangeIndex values). So the tests I added here are confirming that current behaviour in tests, and adding a few checks where Copy-on-Write could delay the copy. \r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47066',
#   'id': 1242351460,
#   'node_id': 'PR_kwDOAA0YD844JmWH',
#   'number': 47066,
#   'title': 'TYP: resolve mypy ignores in core/apply.py',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-19T21:30:33Z',
#   'updated_at': '2022-05-20T14:08:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47066',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47066',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47066.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47066.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/issues/37715',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47064',
#   'id': 1242299667,
#   'node_id': 'PR_kwDOAA0YD844JbFT',
#   'number': 47064,
#   'title': 'TYP: resolve mypy ignores in core/groupby/ops.py',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-19T20:35:46Z',
#   'updated_at': '2022-05-20T12:45:00Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47064',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47064',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47064.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47064.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/issues/37715',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47061',
#   'id': 1241932207,
#   'node_id': 'PR_kwDOAA0YD844IOcl',
#   'number': 47061,
#   'title': 'DOC: Improve reshape\\concat',
#   'user': {'login': 'anetakahle',
#    'id': 29632816,
#    'node_id': 'MDQ6VXNlcjI5NjMyODE2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29632816?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anetakahle',
#    'html_url': 'https://github.com/anetakahle',
#    'followers_url': 'https://api.github.com/users/anetakahle/followers',
#    'following_url': 'https://api.github.com/users/anetakahle/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/anetakahle/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/anetakahle/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/anetakahle/subscriptions',
#    'organizations_url': 'https://api.github.com/users/anetakahle/orgs',
#    'repos_url': 'https://api.github.com/users/anetakahle/repos',
#    'events_url': 'https://api.github.com/users/anetakahle/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/anetakahle/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-05-19T15:09:14Z',
#   'updated_at': '2022-05-20T17:48:25Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47061',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47061',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47061.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47061.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46825\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/reactions',
#    'total_count': 2,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 2,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47058',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47058/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47058/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47058/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47058',
# ...
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 998,
#    'closed_issues': 844,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2022-05-20T12:55:56Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 4,
#   'created_at': '2022-05-14T14:52:23Z',
#   'updated_at': '2022-05-16T20:22:54Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nfile = "pandas_test.dat"\r\n\r\n# Fails\r\ndf = pd.read_csv(file, delimiter=None)\r\n\r\n# Works\r\nfrom astropy.io import ascii\r\ndf = ascii.read(file)\n```\n\n\n### Issue Description\n\n`pandas` fails when trying to guess the delimiter (space) in the test file. `astropy` on the other hand is able to guess it correctly\r\n\r\nThe test file is here [pandas_test.dat.zip](https://github.com/pandas-dev/pandas/files/8693182/pandas_test.dat.zip)\r\n\n\n### Expected Behavior\n\nThe delimiter should be correctly guessed\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\npd.__version__\r\n\'1.4.2\'\r\n```\r\n\r\n</details>\r\n\r\n\r\nThe line `pd.show_versions()` throws the following error:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/pandas/util/_print_versions.py", line 109, in show_versions\r\n    deps = _get_dependency_info()\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/pandas/util/_print_versions.py", line 88, in _get_dependency_info\r\n    mod = import_optional_dependency(modname, errors="ignore")\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/pandas/compat/_optional.py", line 138, in import_optional_dependency\r\n    module = importlib.import_module(name)\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/importlib/__init__.py", line 127, in import_module\r\n    return _bootstrap._gcd_import(name[level:], package, level)\r\n  File "<frozen importlib._bootstrap>", line 1030, in _gcd_import\r\n  File "<frozen importlib._bootstrap>", line 1007, in _find_and_load\r\n  File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked\r\n  File "<frozen importlib._bootstrap>", line 680, in _load_unlocked\r\n  File "<frozen importlib._bootstrap_external>", line 850, in exec_module\r\n  File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/setuptools/__init__.py", line 8, in <module>\r\n    import _distutils_hack.override  # noqa: F401\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/_distutils_hack/override.py", line 1, in <module>\r\n    __import__(\'_distutils_hack\').do_override()\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/_distutils_hack/__init__.py", line 72, in do_override\r\n    ensure_local_distutils()\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/_distutils_hack/__init__.py", line 59, in ensure_local_distutils\r\n    assert \'_distutils\' in core.__file__, core.__file__\r\nAssertionError: /home/gabriel/miniconda3/envs/asteca/lib/python3.9/distutils/core.py\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47024/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47024/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47018',
#   'id': 1235700810,
#   'node_id': 'PR_kwDOAA0YD843zvr_',
#   'number': 47018,
#   'title': 'REF: merge datetime_to_datetime64 into array_to_datetime',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 85,
#    'closed_issues': 781,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-05-20T18:34:43Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 5,
#   'created_at': '2022-05-13T20:51:26Z',
#   'updated_at': '2022-05-20T19:07:23Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47018',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47018',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47018.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47018.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47014',
#   'id': 1235440194,
#   'node_id': 'I_kwDOAA0YD85Jo1JC',
#   'number': 47014,
#   'title': 'ENH: implement DateOffset + datetime64 array',
#   'user': {'login': 'hottwaj',
#    'id': 5629061,
#    'node_id': 'MDQ6VXNlcjU2MjkwNjE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5629061?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hottwaj',
#    'html_url': 'https://github.com/hottwaj',
#    'followers_url': 'https://api.github.com/users/hottwaj/followers',
#    'following_url': 'https://api.github.com/users/hottwaj/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hottwaj/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hottwaj/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hottwaj/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hottwaj/orgs',
#    'repos_url': 'https://api.github.com/users/hottwaj/repos',
#    'events_url': 'https://api.github.com/users/hottwaj/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hottwaj/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False,
#     'description': 'pandas objects compatability with Numpy or Python functions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-05-13T16:15:40Z',
#   'updated_at': '2022-05-16T10:25:43Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nDateOffset + a numpy array of type datetime64 does not work, see examples at the end of this post\r\n\r\n#### Describe the solution you'd like\r\n\r\ncan `__add__` or `__radd__` of DateOffset be changed to implement addition to datetime64 array?\r\n\r\n#### API breaking implications\r\n\r\nI am not the right person to comment, but seems unlikely to have an impact on existing API if it can be done at all\r\n\r\n#### Describe alternatives you've considered\r\n\r\nSorry, not thought of alternatives so far\r\n\r\n#### Code example\r\n\r\n```python\r\n>>> import pandas\r\n>>> import numpy\r\n>>> dates = pandas.Series([pandas.Timestamp(2021, 1, 1) + pandas.Timedelta(days=d) for d in range(1000)])\r\n>>> offset = pandas.offsets.MonthEnd()\r\n\r\n>>> # adding a pandas Timestamp series to an offset obviously works\r\n>>> dates + offset\r\n0     2021-01-31\r\n1     2021-01-31\r\n         ...    \r\n998   2023-09-30\r\n999   2023-09-30\r\nLength: 1000, dtype: datetime64[ns]\r\n\r\n>>> # adding the underlying numpy datetime64 values does not work \r\n>>> offset + dates.values\r\n---------------------------------------------------------------------------\r\nUFuncTypeError                            Traceback (most recent call last)\r\n----> 1 offset + dates.values\r\n\r\nUFuncTypeError: ufunc 'add' cannot use operands with types dtype('O') and dtype('<M8[ns]')\r\n\r\n>>> # slightly different error if we swap the order of the two variables\r\n>>> dates.values + offset\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\n----> 1 dates.values + offset\r\n\r\nTypeError: Concatenation operation is not implemented for NumPy arrays, use np.concatenate() instead. Please do not rely on this error; it may not be given on all Python implementations.\r\n\r\n>>> # the desired result can be achieved by using DateOffset._apply_array() and casting to M8[ns]\r\n>>> offset._apply_array(dates.values).astype('M8[ns]')\r\narray(['2021-01-31T00:00:00.000000000', '2021-01-31T00:00:00.000000000',\r\n       '2021-01-31T00:00:00.000000000', '2021-01-31T00:00:00.000000000',\r\n       '2021-01-31T00:00:00.000000000', '2021-01-31T00:00:00.000000000',\r\n       '2021-01-31T00:00:00.000000000', '2021-01-31T00:00:00.000000000',\r\n       etc])\r\n```\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1)
# Out:
# 30

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 1020496
# 8078968
# 6618166
# 1020496
# 36327192
# 13159005
# 23625371
# 1020496
# 6320308
# 6320308
# 29632816
# 17395686
# 16463246
# 8284922
# 15721311
# 32496804
# 6618166
# 8078968
# 24256554
# 1508012
# 8284922
# 6618166
# 56446640
# 10647082
# 47963215
# 44754681
# 36619387
# 6054951
# 8078968
# 5629061

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47077',
#   'id': 1243492669,
#   'node_id': 'PR_kwDOAA0YD844NWiF',
#   'number': 47077,
#   'title': 'REF: Manager.fast_xs to return SingleBlockManager instead of array',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Related to non-user accessible pandas implementation'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 85,
#    'closed_issues': 781,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-05-20T18:34:43Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-05-20T18:34:43Z',
#   'updated_at': '2022-05-20T18:34:47Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47077',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47077',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47077.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47077.patch',
#    'merged_at': None},
#   'body': 'This is something that I encountered in https://github.com/pandas-dev/pandas/pull/46958, but again something that can be broken off / potentially useful anyway. \r\n\r\nCurrently the `fast_xs` method returns an array, but the only two places where it is being used (`xs` / `_ixs`), this array is directly wrapped in a Series. So by letting ``fast_xs`` return a manager instead, this gives a slight simplification / faster series construction.\r\n\r\nThe reason that it is also useful for https://github.com/pandas-dev/pandas/pull/46958 is because the CoW is handled at the manager level, so when creating a subset of a DataFrame (here in `xs`), ideally that is done by creating a subset manager (with proper references if needed) instead of going through raw arrays (as how it is done for example when accessing a column as a Series).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47077/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47076',
#   'id': 1243412992,
#   'node_id': 'PR_kwDOAA0YD844NFgU',
#   'number': 47076,
#   'title': 'ENH: liboffsets support non-nano',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-20T17:04:10Z',
#   'updated_at': '2022-05-20T17:04:10Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47076',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47076',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47076.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47076.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47076/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47075',
#   'id': 1243374107,
#   'node_id': 'PR_kwDOAA0YD844M9UV',
#   'number': 47075,
#   'title': 'CI: mypy&pyright in manual pre-commit stage',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-20T16:20:41Z',
#   'updated_at': '2022-05-20T19:31:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47075',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47075',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47075.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47075.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/pull/47067#discussion_r877610624',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47075/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47074',
#   'id': 1243359572,
#   'node_id': 'PR_kwDOAA0YD844M6QM',
#   'number': 47074,
#   'title': 'REF: Add Manager.column_setitem to set values into a single column (without intermediate series)',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 49094459,
#     'node_id': 'MDU6TGFiZWw0OTA5NDQ1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals',
#     'name': 'Internals',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Related to non-user accessible pandas implementation'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-20T16:04:53Z',
#   'updated_at': '2022-05-20T17:40:45Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47074',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47074',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47074.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47074.patch',
#    'merged_at': None},
#   'body': 'The `column_setitem` is a method I was adding in https://github.com/pandas-dev/pandas/pull/46958, is something that can be broken off from that PR, and is IMO also a generally useful change.\r\n\r\nCurrently in some cases to set values into a single column (eg `df.loc[idx, "A"] = value`), we create an intermediate Series for that column, set values into that Series, and then update the DataFrame from that updated Series. I think it would be generally good to avoid creating this intermediate Series, and moving the actual/final "set" operation to the internals (as is done for other set operations).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47074/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47073',
#   'id': 1243086499,
#   'node_id': 'I_kwDOAA0YD85KF_6j',
#   'number': 47073,
#   'title': 'BUG: read_csv raises on bad line when should skip or warn',
#   'user': {'login': 'arekkulczycki',
#    'id': 36327192,
#    'node_id': 'MDQ6VXNlcjM2MzI3MTky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36327192?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arekkulczycki',
#    'html_url': 'https://github.com/arekkulczycki',
#    'followers_url': 'https://api.github.com/users/arekkulczycki/followers',
#    'following_url': 'https://api.github.com/users/arekkulczycki/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/arekkulczycki/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/arekkulczycki/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/arekkulczycki/subscriptions',
#    'organizations_url': 'https://api.github.com/users/arekkulczycki/orgs',
#    'repos_url': 'https://api.github.com/users/arekkulczycki/repos',
#    'events_url': 'https://api.github.com/users/arekkulczycki/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/arekkulczycki/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-20T12:33:54Z',
#   'updated_at': '2022-05-20T12:59:22Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nfrom io import StringIO\r\n\r\ncsv = \'col1,col2\\n""malformed","quotes"",\'\r\nio = StringIO(csv)\r\n\r\npd.read_csv(io, on_bad_lines="skip")  # or alternatively "warn"\r\n\r\n# ParserError: Error tokenizing data. C error: EOF inside string starting at row 1\n```\n\n\n### Issue Description\n\nThe combination of \r\n\r\n- malformed text with quotes and a delimiter hidden in between\r\n- doublequote=True\r\n- on_bad_lines="skip"\r\n\r\nraises a ParserError instead of skipping the malformed row.\n\n### Expected Behavior\n\nThe reader skips the malformed row and reads the csv successfully.\n\n### Installed Versions\n\n<details>\r\n\r\ncommit : https://github.com/pandas-dev/pandas/commit/4bfe3d07b4858144c219b9346329027024102ab6\r\npython : 3.8.10.final.0\r\npython-bits : 64\r\nOS : Linux\r\nOS-release : 5.4.0-89-generic\r\nVersion : https://github.com/pandas-dev/pandas/issues/100-Ubuntu SMP Fri Sep 24 14:50:10 UTC 2021\r\nmachine : x86_64\r\nprocessor : x86_64\r\nbyteorder : little\r\nLC_ALL : None\r\nLANG : pl_PL.UTF-8\r\nLOCALE : pl_PL.UTF-8\r\n\r\npandas : 1.4.2\r\nnumpy : 1.22.3\r\npytz : 2022.1\r\ndateutil : 2.8.2\r\npip : 20.0.2\r\nsetuptools : 45.2.0\r\nCython : None\r\npytest : None\r\nhypothesis : None\r\nsphinx : None\r\nblosc : None\r\nfeather : None\r\nxlsxwriter : None\r\nlxml.etree : None\r\nhtml5lib : None\r\npymysql : None\r\npsycopg2 : None\r\njinja2 : None\r\nIPython : 8.3.0\r\npandas_datareader: None\r\nbs4 : 4.8.2\r\nbottleneck : None\r\nbrotli : None\r\nfastparquet : None\r\nfsspec : None\r\ngcsfs : None\r\nmarkupsafe : 1.1.0\r\nmatplotlib : None\r\nnumba : None\r\nnumexpr : None\r\nodfpy : None\r\nopenpyxl : None\r\npandas_gbq : None\r\npyarrow : None\r\npyreadstat : None\r\npyxlsb : None\r\ns3fs : None\r\nscipy : None\r\nsnappy : None\r\nsqlalchemy : None\r\ntables : None\r\ntabulate : None\r\nxarray : None\r\nxlrd : None\r\nxlwt : None\r\nzstandard : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47073/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47072',
#   'id': 1242986429,
#   'node_id': 'PR_kwDOAA0YD844Lq9z',
#   'number': 47072,
#   'title': 'Backport PR #47059 on branch 1.4.x (REGR: Styler buf and encoding in to_latex and to_html)',
#   'user': {'login': 'simonjayhawkins',
#    'id': 13159005,
#    'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simonjayhawkins',
#    'html_url': 'https://github.com/simonjayhawkins',
#    'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#    'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#    'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#    'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#    'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 57395487,
#     'node_id': 'MDU6TGFiZWw1NzM5NTQ4Nw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20HTML',
#     'name': 'IO HTML',
#     'color': '006b75',
#     'default': False,
#     'description': 'read_html, to_html, Styler.apply, Styler.applymap'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/95',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95/labels',
#    'id': 7829734,
#    'node_id': 'MI_kwDOAA0YD84Ad3jm',
#    'number': 95,
#    'title': '1.4.3',
#    'description': 'on-merge: backport to 1.4.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 31,
#    'closed_issues': 52,
#    'state': 'open',
#    'created_at': '2022-04-01T18:18:24Z',
#    'updated_at': '2022-05-20T11:53:29Z',
#    'due_on': '2022-04-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2022-05-20T11:02:17Z',
#   'updated_at': '2022-05-20T17:33:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47072',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47072',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47072.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47072.patch',
#    'merged_at': None},
#   'body': 'Backport PR #47059\r\n\r\nrelease note already backported in #47062',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47072/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47071',
#   'id': 1242983125,
#   'node_id': 'I_kwDOAA0YD85KFmrV',
#   'number': 47071,
#   'title': 'BUG: Reset index regression',
#   'user': {'login': 'znicholls',
#    'id': 23625371,
#    'node_id': 'MDQ6VXNlcjIzNjI1Mzcx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23625371?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/znicholls',
#    'html_url': 'https://github.com/znicholls',
#    'followers_url': 'https://api.github.com/users/znicholls/followers',
#    'following_url': 'https://api.github.com/users/znicholls/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/znicholls/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/znicholls/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/znicholls/subscriptions',
#    'organizations_url': 'https://api.github.com/users/znicholls/orgs',
#    'repos_url': 'https://api.github.com/users/znicholls/repos',
#    'events_url': 'https://api.github.com/users/znicholls/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/znicholls/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False,
#     'description': 'pandas objects compatability with Numpy or Python functions'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/95',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/95/labels',
#    'id': 7829734,
#    'node_id': 'MI_kwDOAA0YD84Ad3jm',
#    'number': 95,
#    'title': '1.4.3',
#    'description': 'on-merge: backport to 1.4.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 31,
#    'closed_issues': 52,
#    'state': 'open',
#    'created_at': '2022-04-01T18:18:24Z',
#    'updated_at': '2022-05-20T11:53:29Z',
#    'due_on': '2022-04-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-05-20T10:59:01Z',
#   'updated_at': '2022-05-20T11:53:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nfrom pandas import DataFrame, Index\r\nimport xarray\r\n\r\ndf = DataFrame(\r\n    [[1, 2], [3, 4]],\r\n    columns=xarray.cftime_range("0001", periods=2),\r\n    index=Index(["hi", "bye"], name="string"),\r\n)\r\n# currently fails with TypeError\r\nres = df.reset_index()\n```\n\n\n### Issue Description\n\nThe above leads to a type error.\n\n### Expected Behavior\n\nReset index. I would guess that the columns should be downcast from `CFTimeIndex` to `Index` with object type but maybe there\'s a better option.\n\n### Installed Versions\n\n<details>\r\n\r\nminiconda3/envs/pandas-dev/lib/python3.8/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 1def8d9f3f0690ae93cbf611246f80f79a0faeaa\r\npython           : 3.8.13.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 19.6.0\r\nVersion          : Darwin Kernel Version 19.6.0: Mon Apr 18 21:50:40 PDT 2022; root:xnu-6153.141.62~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_AU.UTF-8\r\nLOCALE           : en_AU.UTF-8\r\n\r\npandas           : 1.5.0.dev0+798.g1def8d9f3f\r\nnumpy            : 1.22.3\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\npip              : 22.0.4\r\nsetuptools       : 62.3.2\r\nCython           : 0.29.30\r\npytest           : 7.1.2\r\nhypothesis       : 6.46.7\r\nsphinx           : 4.5.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : 3.0.3\r\nlxml.etree       : 4.8.0\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.3\r\nIPython          : 8.3.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : 1.3.4\r\nbrotli           : \r\nfastparquet      : 0.8.1\r\nfsspec           : 2021.11.0\r\ngcsfs            : 2021.11.0\r\nmatplotlib       : 3.5.2\r\nnumba            : 0.53.1\r\nnumexpr          : 2.8.0\r\nodfpy            : None\r\nopenpyxl         : 3.0.9\r\npandas_gbq       : None\r\npyarrow          : 8.0.0\r\npyreadstat       : 1.1.6\r\npyxlsb           : None\r\ns3fs             : 2021.11.0\r\nscipy            : 1.8.0\r\nsnappy           : \r\nsqlalchemy       : 1.4.36\r\ntables           : 3.7.0\r\ntabulate         : 0.8.9\r\nxarray           : 2022.3.0\r\nxlrd             : 2.0.1\r\nxlwt             : 1.3.0\r\nzstandard        : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47071/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47070',
#   'id': 1242852588,
#   'node_id': 'PR_kwDOAA0YD844LOHh',
#   'number': 47070,
#   'title': 'TST: add copy/view test for setting columns with an array/series',
#   'user': {'login': 'jorisvandenbossche',
#    'id': 1020496,
#    'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jorisvandenbossche',
#    'html_url': 'https://github.com/jorisvandenbossche',
#    'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#    'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#    'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#    'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 85,
#    'closed_issues': 781,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-05-20T18:34:43Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-05-20T09:06:10Z',
#   'updated_at': '2022-05-20T14:40:47Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47070',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47070',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47070.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47070.patch',
#    'merged_at': None},
#   'body': 'Similarly as https://github.com/pandas-dev/pandas/pull/46979, this is adding some test cases explicitly testing copy/view behaviour for a specific topic: if we set an array or series as a column, is the new column a copy or a view of the original data? \r\nAt this moment, we actually already do make a copy of that data (with one exception being the cached RangeIndex values). So the tests I added here are confirming that current behaviour in tests, and adding a few checks where Copy-on-Write could delay the copy. \r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47070/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47066',
#   'id': 1242351460,
#   'node_id': 'PR_kwDOAA0YD844JmWH',
#   'number': 47066,
#   'title': 'TYP: resolve mypy ignores in core/apply.py',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-19T21:30:33Z',
#   'updated_at': '2022-05-20T14:08:29Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47066',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47066',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47066.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47066.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/issues/37715',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47066/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47064',
#   'id': 1242299667,
#   'node_id': 'PR_kwDOAA0YD844JbFT',
#   'number': 47064,
#   'title': 'TYP: resolve mypy ignores in core/groupby/ops.py',
#   'user': {'login': 'iasoon',
#    'id': 6320308,
#    'node_id': 'MDQ6VXNlcjYzMjAzMDg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6320308?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iasoon',
#    'html_url': 'https://github.com/iasoon',
#    'followers_url': 'https://api.github.com/users/iasoon/followers',
#    'following_url': 'https://api.github.com/users/iasoon/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/iasoon/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/iasoon/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/iasoon/subscriptions',
#    'organizations_url': 'https://api.github.com/users/iasoon/orgs',
#    'repos_url': 'https://api.github.com/users/iasoon/repos',
#    'events_url': 'https://api.github.com/users/iasoon/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/iasoon/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-05-19T20:35:46Z',
#   'updated_at': '2022-05-20T12:45:00Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47064',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47064',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47064.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47064.patch',
#    'merged_at': None},
#   'body': 'xref https://github.com/pandas-dev/pandas/issues/37715',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47064/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47061',
#   'id': 1241932207,
#   'node_id': 'PR_kwDOAA0YD844IOcl',
#   'number': 47061,
#   'title': 'DOC: Improve reshape\\concat',
#   'user': {'login': 'anetakahle',
#    'id': 29632816,
#    'node_id': 'MDQ6VXNlcjI5NjMyODE2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29632816?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/anetakahle',
#    'html_url': 'https://github.com/anetakahle',
#    'followers_url': 'https://api.github.com/users/anetakahle/followers',
#    'following_url': 'https://api.github.com/users/anetakahle/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/anetakahle/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/anetakahle/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/anetakahle/subscriptions',
#    'organizations_url': 'https://api.github.com/users/anetakahle/orgs',
#    'repos_url': 'https://api.github.com/users/anetakahle/repos',
#    'events_url': 'https://api.github.com/users/anetakahle/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/anetakahle/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-05-19T15:09:14Z',
#   'updated_at': '2022-05-20T17:48:25Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47061',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47061',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47061.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47061.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46825\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/reactions',
#    'total_count': 2,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 2,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47061/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47058',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47058/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47058/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47058/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47058',
# ...
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 998,
#    'closed_issues': 844,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2022-05-20T12:55:56Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 4,
#   'created_at': '2022-05-14T14:52:23Z',
#   'updated_at': '2022-05-16T20:22:54Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nfile = "pandas_test.dat"\r\n\r\n# Fails\r\ndf = pd.read_csv(file, delimiter=None)\r\n\r\n# Works\r\nfrom astropy.io import ascii\r\ndf = ascii.read(file)\n```\n\n\n### Issue Description\n\n`pandas` fails when trying to guess the delimiter (space) in the test file. `astropy` on the other hand is able to guess it correctly\r\n\r\nThe test file is here [pandas_test.dat.zip](https://github.com/pandas-dev/pandas/files/8693182/pandas_test.dat.zip)\r\n\n\n### Expected Behavior\n\nThe delimiter should be correctly guessed\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\npd.__version__\r\n\'1.4.2\'\r\n```\r\n\r\n</details>\r\n\r\n\r\nThe line `pd.show_versions()` throws the following error:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/pandas/util/_print_versions.py", line 109, in show_versions\r\n    deps = _get_dependency_info()\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/pandas/util/_print_versions.py", line 88, in _get_dependency_info\r\n    mod = import_optional_dependency(modname, errors="ignore")\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/pandas/compat/_optional.py", line 138, in import_optional_dependency\r\n    module = importlib.import_module(name)\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/importlib/__init__.py", line 127, in import_module\r\n    return _bootstrap._gcd_import(name[level:], package, level)\r\n  File "<frozen importlib._bootstrap>", line 1030, in _gcd_import\r\n  File "<frozen importlib._bootstrap>", line 1007, in _find_and_load\r\n  File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked\r\n  File "<frozen importlib._bootstrap>", line 680, in _load_unlocked\r\n  File "<frozen importlib._bootstrap_external>", line 850, in exec_module\r\n  File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/setuptools/__init__.py", line 8, in <module>\r\n    import _distutils_hack.override  # noqa: F401\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/_distutils_hack/override.py", line 1, in <module>\r\n    __import__(\'_distutils_hack\').do_override()\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/_distutils_hack/__init__.py", line 72, in do_override\r\n    ensure_local_distutils()\r\n  File "/home/gabriel/miniconda3/envs/asteca/lib/python3.9/site-packages/_distutils_hack/__init__.py", line 59, in ensure_local_distutils\r\n    assert \'_distutils\' in core.__file__, core.__file__\r\nAssertionError: /home/gabriel/miniconda3/envs/asteca/lib/python3.9/distutils/core.py\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47024/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47024/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47018',
#   'id': 1235700810,
#   'node_id': 'PR_kwDOAA0YD843zvr_',
#   'number': 47018,
#   'title': 'REF: merge datetime_to_datetime64 into array_to_datetime',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127681,
#     'node_id': 'MDU6TGFiZWwxMjc2ODE=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#     'name': 'Refactor',
#     'color': 'FCE94F',
#     'default': False,
#     'description': 'Internal refactoring of code'},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/92',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/92/labels',
#    'id': 7530006,
#    'node_id': 'MI_kwDOAA0YD84AcuYW',
#    'number': 92,
#    'title': '1.5',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 85,
#    'closed_issues': 781,
#    'state': 'open',
#    'created_at': '2021-12-31T21:51:13Z',
#    'updated_at': '2022-05-20T18:34:43Z',
#    'due_on': '2022-06-30T07:00:00Z',
#    'closed_at': None},
#   'comments': 5,
#   'created_at': '2022-05-13T20:51:26Z',
#   'updated_at': '2022-05-20T19:07:23Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47018',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47018',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47018.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47018.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47018/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47014',
#   'id': 1235440194,
#   'node_id': 'I_kwDOAA0YD85Jo1JC',
#   'number': 47014,
#   'title': 'ENH: implement DateOffset + datetime64 array',
#   'user': {'login': 'hottwaj',
#    'id': 5629061,
#    'node_id': 'MDQ6VXNlcjU2MjkwNjE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5629061?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hottwaj',
#    'html_url': 'https://github.com/hottwaj',
#    'followers_url': 'https://api.github.com/users/hottwaj/followers',
#    'following_url': 'https://api.github.com/users/hottwaj/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hottwaj/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/hottwaj/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hottwaj/subscriptions',
#    'organizations_url': 'https://api.github.com/users/hottwaj/orgs',
#    'repos_url': 'https://api.github.com/users/hottwaj/repos',
#    'events_url': 'https://api.github.com/users/hottwaj/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/hottwaj/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 76865106,
#     'node_id': 'MDU6TGFiZWw3Njg2NTEwNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Compat',
#     'name': 'Compat',
#     'color': '0052cc',
#     'default': False,
#     'description': 'pandas objects compatability with Numpy or Python functions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-05-13T16:15:40Z',
#   'updated_at': '2022-05-16T10:25:43Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "#### Is your feature request related to a problem?\r\n\r\nDateOffset + a numpy array of type datetime64 does not work, see examples at the end of this post\r\n\r\n#### Describe the solution you'd like\r\n\r\ncan `__add__` or `__radd__` of DateOffset be changed to implement addition to datetime64 array?\r\n\r\n#### API breaking implications\r\n\r\nI am not the right person to comment, but seems unlikely to have an impact on existing API if it can be done at all\r\n\r\n#### Describe alternatives you've considered\r\n\r\nSorry, not thought of alternatives so far\r\n\r\n#### Code example\r\n\r\n```python\r\n>>> import pandas\r\n>>> import numpy\r\n>>> dates = pandas.Series([pandas.Timestamp(2021, 1, 1) + pandas.Timedelta(days=d) for d in range(1000)])\r\n>>> offset = pandas.offsets.MonthEnd()\r\n\r\n>>> # adding a pandas Timestamp series to an offset obviously works\r\n>>> dates + offset\r\n0     2021-01-31\r\n1     2021-01-31\r\n         ...    \r\n998   2023-09-30\r\n999   2023-09-30\r\nLength: 1000, dtype: datetime64[ns]\r\n\r\n>>> # adding the underlying numpy datetime64 values does not work \r\n>>> offset + dates.values\r\n---------------------------------------------------------------------------\r\nUFuncTypeError                            Traceback (most recent call last)\r\n----> 1 offset + dates.values\r\n\r\nUFuncTypeError: ufunc 'add' cannot use operands with types dtype('O') and dtype('<M8[ns]')\r\n\r\n>>> # slightly different error if we swap the order of the two variables\r\n>>> dates.values + offset\r\n---------------------------------------------------------------------------\r\nTypeError                                 Traceback (most recent call last)\r\n----> 1 dates.values + offset\r\n\r\nTypeError: Concatenation operation is not implemented for NumPy arrays, use np.concatenate() instead. Please do not rely on this error; it may not be given on all Python implementations.\r\n\r\n>>> # the desired result can be achieved by using DateOffset._apply_array() and casting to M8[ns]\r\n>>> offset._apply_array(dates.values).astype('M8[ns]')\r\narray(['2021-01-31T00:00:00.000000000', '2021-01-31T00:00:00.000000000',\r\n       '2021-01-31T00:00:00.000000000', '2021-01-31T00:00:00.000000000',\r\n       '2021-01-31T00:00:00.000000000', '2021-01-31T00:00:00.000000000',\r\n       '2021-01-31T00:00:00.000000000', '2021-01-31T00:00:00.000000000',\r\n       etc])\r\n```\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47014/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
df2 = pd.DataFrame(data1 , columns=['id','url' , 'repository_url' , 'labels_url','user'])

# %%
df2.to_csv('json_res.csv')

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FA55-E833
#
#  Directory of C:\Users\win10\jupyter\Complete Python Module-20210227T092441Z-001\Complete Python Module\16-17. Pandas-Numpy
#
# 02/27/2022  12:15 PM    <DIR>          .
# 02/27/2022  12:15 PM    <DIR>          ..
# 02/27/2022  10:25 AM    <DIR>          .ipynb_checkpoints
# 07/07/2021  08:04 PM           107,005 16.1 Pandas file read and write operation.ipynb
# 06/01/2021  06:38 AM           138,431 16.2 Pandas data manipulation .ipynb
# 06/01/2021  06:38 AM           105,034 16.3 Pandas data manipulation_continue .ipynb
# 07/07/2021  08:04 PM            94,904 17. Numpy in details.ipynb
# 02/26/2022  12:05 PM             1,173 addresses.csv
# 02/26/2022  12:05 PM             1,589 contacts.csv
# 02/27/2022  10:55 AM             5,644 cricket.csv
# 04/11/2021  06:07 AM    <DIR>          example_files
# 02/26/2022  12:05 PM               277 holiday_schedules.csv
# 02/27/2022  12:15 PM            34,688 json_res.csv
# 02/26/2022  12:05 PM            18,015 locations.csv
# 02/26/2022  01:00 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 02/26/2022  01:00 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 02/26/2022  01:00 PM            71,993 LUSID Excel - Manage Orders.xlsx
# 02/26/2022  01:00 PM           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 02/26/2022  01:00 PM           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 02/26/2022  01:00 PM           136,632 LUSID Excel - Setting up your market data.xlsx
# 02/26/2022  12:05 PM             1,610 mail_addresses.csv
# 08/07/2020  11:06 PM                 0 my_database4.db
# 08/07/2020  11:07 PM             8,192 my_database5.db
# 08/08/2020  03:48 AM           189,104 mydata.h5
# 08/07/2020  11:06 PM             8,192 mydata2.sqlite
# 02/27/2022  10:49 AM            78,960 NBA.csv
# 11/06/2021  09:38 PM            39,413 Numpy.ipynb
# 02/26/2022  12:05 PM             2,281 organizations.csv
# 02/26/2022  01:04 PM           263,960 pandas data manupulation.ipynb
# 02/27/2022  12:13 PM           591,290 pandas day 2.ipynb
# 02/26/2022  01:51 PM           289,880 Pandas.ipynb
# 02/26/2022  12:05 PM             2,092 phones.csv
# 02/26/2022  12:05 PM                60 programs.csv
# 02/26/2022  12:05 PM               350 regular_schedules.csv
# 02/26/2022  12:31 PM               254 sample_test.csv
# 02/26/2022  12:05 PM            19,128 services.csv
# 02/26/2022  12:17 PM            14,578 taxonomy.csv
# 11/06/2021  10:19 PM             5,122 Untitled1.ipynb
#               34 File(s)      2,874,678 bytes
#                4 Dir(s)  470,423,760,896 bytes free
