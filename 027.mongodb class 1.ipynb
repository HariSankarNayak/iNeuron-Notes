# %%
pip install "pymongo[srv]"
# Out:
# Collecting pymongo[srv]
#   Downloading pymongo-4.16.0-cp310-cp310-win_amd64.whl.metadata (10.0 kB)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo[srv])
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading pymongo-4.16.0-cp310-cp310-win_amd64.whl (804 kB)
#    ---------------------------------------- 0.0/804.8 kB ? eta -:--:--
#    ---------------------------------------- 804.8/804.8 kB 17.5 MB/s  0:00:00
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# Installing collected packages: dnspython, pymongo
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    -------------------- ------------------- 1/2 [pymongo]
#    -------------------- ------------------- 1/2 [pymongo]
#    ---------------------------------------- 2/2 [pymongo]
#
# Successfully installed dnspython-2.8.0 pymongo-4.16.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: pymongo 4.16.0 does not provide the extra 'srv'

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://mongodb:mongodb@cluster0.ahgzfjs.mongodb.net/?appName=Cluster0")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['ac-zvbguop-shard-00-02.ahgzfjs.mongodb.net:27017', 'ac-zvbguop-shard-00-01.ahgzfjs.mongodb.net:27017', 'ac-zvbguop-shard-00-00.ahgzfjs.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-mz3umh-shard-0', tls=True), 'test')

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\nayak\anaconda3\envs\ineuron_env\lib\site-packages (4.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\nayak\anaconda3\envs\ineuron_env\lib\site-packages (from pymongo[srv]) (2.8.0)
# WARNING: pymongo 4.16.0 does not provide the extra 'srv'

# %%
# !pip install dnspython
# Out:
# Requirement already satisfied: dnspython in c:\users\nayak\anaconda3\envs\ineuron_env\lib\site-packages (2.8.0)

# %%
import pymongo
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'test')

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'test')

# %%
db = client.test1

# %%
db = client['iNeurondb']

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'iNeurondb', 'local']

# %%
coll1 = db['ineuron_collection']

# %%
dict1 = {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
}#called as one document

# %%
coll1.insert_one(dict1)
# Out:
# InsertOneResult(ObjectId('69d6a1567ba9f32ddec71f08'), acknowledged=True)

# %%
dict3 = {
    "_id" :"fsdfafdsafasfdfdgasdf",
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited",
    "phone_number": "34534534635"
}

# %%
coll1.insert_one(dict3)
# Out:
# InsertOneResult('fsdfafdsafasfdfdgasdf', acknowledged=True)

# %%
list1 = [
        {
            "item": "canvas",
            "qty": 100,
            "size": {"h": 28, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "journal",
            "qty": 25,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mat",
            "qty": 85,
            "size": {"h": 27.9, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mousepad",
            "qty": 25,
            "size": {"h": 19, "w": 22.85, "uom": "cm"},
            "status": "P",
        },
        {
            "item": "notebook",
            "qty": 50,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "P",
        },
        {
            "item": "paper",
            "qty": 100,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "D",
        },
        {
            "item": "planner",
            "qty": 75,
            "size": {"h": 22.85, "w": 30, "uom": "cm"},
            "status": "D",
        },
        {
            "item": "postcard",
            "qty": 45,
            "size": {"h": 10, "w": 15.25, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketchbook",
            "qty": 80,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketch pad",
            "qty": 95,
            "size": {"h": 22.85, "w": 30.5, "uom": "cm"},
            "status": "A",
        },
    ]

# %%
coll1.insert_many(list1)
# Out:
# InsertManyResult([ObjectId('69d6a1567ba9f32ddec71f09'), ObjectId('69d6a1567ba9f32ddec71f0a'), ObjectId('69d6a1567ba9f32ddec71f0b'), ObjectId('69d6a1567ba9f32ddec71f0c'), ObjectId('69d6a1567ba9f32ddec71f0d'), ObjectId('69d6a1567ba9f32ddec71f0e'), ObjectId('69d6a1567ba9f32ddec71f0f'), ObjectId('69d6a1567ba9f32ddec71f10'), ObjectId('69d6a1567ba9f32ddec71f11'), ObjectId('69d6a1567ba9f32ddec71f12')], acknowledged=True)

# %%
list2 = [
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
]

# %%
coll1.insert_many(list2)
# Out:
# InsertManyResult([ObjectId('69d6a1567ba9f32ddec71f13'), ObjectId('69d6a1567ba9f32ddec71f14'), ObjectId('69d6a1567ba9f32ddec71f15'), ObjectId('69d6a1567ba9f32ddec71f16'), ObjectId('69d6a1567ba9f32ddec71f17')], acknowledged=True)

# %%
# Break till 11.48 AM IST

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f09'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0a'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0b'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0c'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0d'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0e'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0f'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f10'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f11'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f12'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find({"name" :"sudhanshu"}):
    print(i)
# Out:
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find({"name" :{"$in" :["sudhan" , "sudhanshu" ,"sudh"]},'email_id':"sudhanshu@ineuron.ai"}):
    print(i)
# Out:
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.find_one()
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'),
#  'item': 'canvas',
#  'qty': 400,
#  'size': {'h': 28, 'w': 35.5, 'uom': 'cm'},
#  'status': 'A'}

# %%
for i in coll1.find({"qty":{'$gte' : 25}}):
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f09'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0a'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0b'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0c'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0d'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0e'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0f'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f10'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f11'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f12'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}

# %%
for i in coll1.find({"qty":{'$lte' : 25}}):
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0a'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0c'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f09'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0a'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0b'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0c'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0d'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0e'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0f'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f10'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f11'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f12'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.update_many({'name': 'sudhanshu'},{"$set":{'name': 'sudhanshu kumar'}})
# Out:
# UpdateResult({'n': 7, 'nModified': 7, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f09'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0a'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0b'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0c'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0d'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0e'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0f'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f10'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f11'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f12'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find().limit(2):
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}

# %%
for i in coll1.find({'qty' : {'$not' :{"$gte" : 25}}}):
    print(i)
# Out:
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find({'qty' : {'$not' :{"$lte" : 25}}}):
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f09'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0b'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0d'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0e'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0f'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f10'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f11'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f12'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f09'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0a'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0b'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0c'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0d'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0e'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0f'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f10'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f11'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f12'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.find_one_and_update({'item': 'journal'} , {"$set" : {"qty" : 250}})
# Out:
# {'_id': ObjectId('698242cf144f82200cc07327'),
#  'item': 'journal',
#  'qty': 400,
#  'size': {'h': 14, 'w': 21, 'uom': 'cm'},
#  'status': 'A'}

# %%
for i in coll1.find() : 
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 250, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f09'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0a'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0b'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0c'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0d'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0e'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0f'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f10'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f11'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f12'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.update_many({'qty': {"$gt" : 50}} , {"$set" :{'qty' : 400}})
# Out:
# UpdateResult({'n': 13, 'nModified': 7, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
for i in coll1.find() :
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f08'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f09'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0a'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0b'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0c'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0d'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0e'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0f'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f10'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f11'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f12'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f13'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f14'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f15'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f16'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f17'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.delete_many({'name': 'sudhanshu kumar'})
# Out:
# DeleteResult({'n': 7, 'ok': 1.0}, acknowledged=True)

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f09'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0a'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0b'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0c'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0d'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0e'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f0f'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f10'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f11'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('69d6a1567ba9f32ddec71f12'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
