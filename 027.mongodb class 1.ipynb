# %%
pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\nayak\anaconda3\lib\site-packages (4.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\nayak\anaconda3\lib\site-packages (from pymongo[srv]) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: pymongo 4.16.0 does not provide the extra 'srv'

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://mongodb:mongodb@cluster0.ahgzfjs.mongodb.net/?appName=Cluster0")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['ac-zvbguop-shard-00-01.ahgzfjs.mongodb.net:27017', 'ac-zvbguop-shard-00-00.ahgzfjs.mongodb.net:27017', 'ac-zvbguop-shard-00-02.ahgzfjs.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-mz3umh-shard-0', tls=True), 'test')

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\nayak\anaconda3\lib\site-packages (4.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\nayak\anaconda3\lib\site-packages (from pymongo[srv]) (2.7.0)
# WARNING: pymongo 4.16.0 does not provide the extra 'srv'

# %%
# !pip install dnspython
# Out:
# Requirement already satisfied: dnspython in c:\users\nayak\anaconda3\lib\site-packages (2.7.0)

# %%
import pymongo
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'test')

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'test')

# %%
db = client.test1

# %%
db = client['iNeurondb']

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'iNeurondb', 'local']

# %%
coll1 = db['ineuron_collection']

# %%
dict1 = {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
}#called as one document

# %%
coll1.insert_one(dict1)
# Out:
# InsertOneResult(ObjectId('698242cf144f82200cc07325'), acknowledged=True)

# %%
dict3 = {
    "_id" :"fsdfafdsafasfdfdgasdf",
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited",
    "phone_number": "34534534635"
}

# %%
coll1.insert_one(dict3)
# Out:
# InsertOneResult('fsdfafdsafasfdfdgasdf', acknowledged=True)

# %%
list1 = [
        {
            "item": "canvas",
            "qty": 100,
            "size": {"h": 28, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "journal",
            "qty": 25,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mat",
            "qty": 85,
            "size": {"h": 27.9, "w": 35.5, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "mousepad",
            "qty": 25,
            "size": {"h": 19, "w": 22.85, "uom": "cm"},
            "status": "P",
        },
        {
            "item": "notebook",
            "qty": 50,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "P",
        },
        {
            "item": "paper",
            "qty": 100,
            "size": {"h": 8.5, "w": 11, "uom": "in"},
            "status": "D",
        },
        {
            "item": "planner",
            "qty": 75,
            "size": {"h": 22.85, "w": 30, "uom": "cm"},
            "status": "D",
        },
        {
            "item": "postcard",
            "qty": 45,
            "size": {"h": 10, "w": 15.25, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketchbook",
            "qty": 80,
            "size": {"h": 14, "w": 21, "uom": "cm"},
            "status": "A",
        },
        {
            "item": "sketch pad",
            "qty": 95,
            "size": {"h": 22.85, "w": 30.5, "uom": "cm"},
            "status": "A",
        },
    ]

# %%
coll1.insert_many(list1)
# Out:
# InsertManyResult([ObjectId('698242cf144f82200cc07326'), ObjectId('698242cf144f82200cc07327'), ObjectId('698242cf144f82200cc07328'), ObjectId('698242cf144f82200cc07329'), ObjectId('698242cf144f82200cc0732a'), ObjectId('698242cf144f82200cc0732b'), ObjectId('698242cf144f82200cc0732c'), ObjectId('698242cf144f82200cc0732d'), ObjectId('698242cf144f82200cc0732e'), ObjectId('698242cf144f82200cc0732f')], acknowledged=True)

# %%
list2 = [
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
    {
    "name" :"sudhanshu",
    "email_id" :"sudhanshu@ineuron.ai",
    "product" : ["one neuron" , "tech neuron" , "kids neuron " , "drone fleetmatics"],
    "company" : "ineuron intelligence private limited"
},
]

# %%
coll1.insert_many(list2)
# Out:
# InsertManyResult([ObjectId('698242cf144f82200cc07330'), ObjectId('698242cf144f82200cc07331'), ObjectId('698242cf144f82200cc07332'), ObjectId('698242cf144f82200cc07333'), ObjectId('698242cf144f82200cc07334')], acknowledged=True)

# %%
# Break till 11.48 AM IST

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find({"name" :"sudhanshu"}):
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find({"name" :{"$in" :["sudhan" , "sudhanshu" ,"sudh"]},'email_id':"sudhanshu@ineuron.ai"}):
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.find_one()
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'),
#  'name': 'sudhanshu',
#  'email_id': 'sudhanshu@ineuron.ai',
#  'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'],
#  'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find({"qty":{'$gte' : 25}}):
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}

# %%
for i in coll1.find({"qty":{'$lte' : 25}}):
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.update_many({'name': 'sudhanshu'},{"$set":{'name': 'sudhanshu kumar'}})
# Out:
# UpdateResult({'n': 8, 'nModified': 8, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find().limit(2):
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find({'qty' : {'$not' :{"$gte" : 25}}}):
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find({'qty' : {'$not' :{"$lte" : 25}}}):
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 25, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.find_one_and_update({'item': 'journal'} , {"$set" : {"qty" : 250}})
# Out:
# {'_id': ObjectId('698242cf144f82200cc07327'),
#  'item': 'journal',
#  'qty': 25,
#  'size': {'h': 14, 'w': 21, 'uom': 'cm'},
#  'status': 'A'}

# %%
for i in coll1.find() : 
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 100, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 250, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 85, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 100, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 75, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 80, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 95, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.update_many({'qty': {"$gt" : 50}} , {"$set" :{'qty' : 400}})
# Out:
# UpdateResult({'n': 7, 'nModified': 7, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
for i in coll1.find() :
    print(i)
# Out:
# {'_id': ObjectId('698242b7144f82200cc07322'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07325'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': 'fsdfafdsafasfdfdgasdf', 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited', 'phone_number': '34534534635'}
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07330'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07331'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07332'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07333'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}
# {'_id': ObjectId('698242cf144f82200cc07334'), 'name': 'sudhanshu kumar', 'email_id': 'sudhanshu@ineuron.ai', 'product': ['one neuron', 'tech neuron', 'kids neuron ', 'drone fleetmatics'], 'company': 'ineuron intelligence private limited'}

# %%
coll1.delete_many({'name': 'sudhanshu kumar'})
# Out:
# DeleteResult({'n': 8, 'ok': 1.0}, acknowledged=True)

# %%
for i in coll1.find():
    print(i)
# Out:
# {'_id': ObjectId('698242cf144f82200cc07326'), 'item': 'canvas', 'qty': 400, 'size': {'h': 28, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07327'), 'item': 'journal', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07328'), 'item': 'mat', 'qty': 400, 'size': {'h': 27.9, 'w': 35.5, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc07329'), 'item': 'mousepad', 'qty': 25, 'size': {'h': 19, 'w': 22.85, 'uom': 'cm'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732a'), 'item': 'notebook', 'qty': 50, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'P'}
# {'_id': ObjectId('698242cf144f82200cc0732b'), 'item': 'paper', 'qty': 400, 'size': {'h': 8.5, 'w': 11, 'uom': 'in'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732c'), 'item': 'planner', 'qty': 400, 'size': {'h': 22.85, 'w': 30, 'uom': 'cm'}, 'status': 'D'}
# {'_id': ObjectId('698242cf144f82200cc0732d'), 'item': 'postcard', 'qty': 45, 'size': {'h': 10, 'w': 15.25, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732e'), 'item': 'sketchbook', 'qty': 400, 'size': {'h': 14, 'w': 21, 'uom': 'cm'}, 'status': 'A'}
# {'_id': ObjectId('698242cf144f82200cc0732f'), 'item': 'sketch pad', 'qty': 400, 'size': {'h': 22.85, 'w': 30.5, 'uom': 'cm'}, 'status': 'A'}
