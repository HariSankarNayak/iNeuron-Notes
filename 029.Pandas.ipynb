# %%
import pandas as pd 
import os

# %%
path="D:\\SelfProject\\iNeuron\\Python\\data\\sample-csv\\titanic.csv"
os.path.relpath(path)
# Out:
# 'data\\sample-csv\\titanic.csv'

# %%
# Files :
    
#     sample csv file - https://github.com/codeforamerica/ohana-api/tree/master/data/sample-csv
#     Titanic - https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
#     excel file - https://github.com/finbourne/sample-excel

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is F8E2-D371
#
#  Directory of d:\SelfProject\iNeuron\Python
#
# 04-02-2026  00:54    <DIR>          .
# 04-04-2023  00:17    <DIR>          ..
# 04-02-2026  00:42    <DIR>          .git
# 04-04-2023  00:18    <DIR>          .ipynb_checkpoints
# 04-04-2023  00:17            23,057 000.python basic.ipynb
# 04-04-2023  00:17            23,471 001.python basic.ipynb
# 04-04-2023  00:17            16,952 002.whileloop.ipynb
# 04-04-2023  00:17            17,533 003.Forloop.ipynb
# 04-04-2023  00:17            39,935 004.python string and list manupulation.ipynb
# 04-04-2023  00:17            69,090 004.python string and list manupulation-nov.ipynb
# 04-04-2023  00:17            56,644 005.list manupulaton.ipynb
# 04-04-2023  00:17            54,898 006.TUPLE SET AND DICT-bckup.ipynb
# 04-04-2023  00:17            59,358 006.Tuples , set , dict .ipynb
# 04-04-2023  00:17            27,917 007.Function in pyton  (1).ipynb
# ...

# %%
pd.read_csv('.\data\sample-csv\phones.csv')
# Out:
#     id  contact_id  location_id  organization_id  service_id  country_prefix  \
# 0    1         NaN          1.0              NaN         NaN             NaN
# 1    2         NaN          1.0              NaN         NaN             NaN
# 2    3         NaN          2.0              NaN         NaN             NaN
# 3    4         NaN          2.0              NaN         NaN             NaN
# 4    5         NaN          3.0              NaN         NaN             NaN
# 5    6         NaN          3.0              NaN         NaN             NaN
# 6    7         NaN          4.0              NaN         NaN             NaN
# 7    8         NaN          4.0              NaN         NaN             NaN
# 8    9         NaN          5.0              NaN         NaN             NaN
# 9   10         NaN          5.0              NaN         NaN             NaN
# 10  11         NaN          6.0              NaN         NaN             NaN
# ...

# %%
pd.read_csv(r'.\data\sample-csv\titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv('.\data\sample-csv\services.csv')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
# pd.read_csv('.\data\sample-csv\taxonomy.csv')
# \t → means TAB character

# \s → invalid escape

# \d → invalid escape
pd.read_csv('.\data\sample-csv\programs.csv')
# Out:
#    id  organization_id           name  alternate_name
# 0   1                1  Defeat Hunger             NaN

# %%
# df = pd.read_csv('taxonomy.csv')
df = pd.read_csv(r'.\data\sample-csv\taxonomy.csv')

# %%
a = 1

# %%
type(a)
# Out:
# int

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is F8E2-D371
#
#  Directory of d:\SelfProject\iNeuron\Python
#
# 04-02-2026  00:54    <DIR>          .
# 04-04-2023  00:17    <DIR>          ..
# 04-02-2026  00:42    <DIR>          .git
# 04-04-2023  00:18    <DIR>          .ipynb_checkpoints
# 04-04-2023  00:17            23,057 000.python basic.ipynb
# 04-04-2023  00:17            23,471 001.python basic.ipynb
# 04-04-2023  00:17            16,952 002.whileloop.ipynb
# 04-04-2023  00:17            17,533 003.Forloop.ipynb
# 04-04-2023  00:17            39,935 004.python string and list manupulation.ipynb
# 04-04-2023  00:17            69,090 004.python string and list manupulation-nov.ipynb
# 04-04-2023  00:17            56,644 005.list manupulaton.ipynb
# 04-04-2023  00:17            54,898 006.TUPLE SET AND DICT-bckup.ipynb
# 04-04-2023  00:17            59,358 006.Tuples , set , dict .ipynb
# 04-04-2023  00:17            27,917 007.Function in pyton  (1).ipynb
# ...

# %%
pd.read_csv('.\data\sample-csv\mail_addresses.csv',header=None)
# Out:
#      0            1                                    2  \
# 0   id  location_id                            attention
# 1    1            1   Fair Oaks Intergenerational Center
# 2    2            2           PFS Second Career Services
# 3    3            3           PFS Senior Peer Counseling
# 4    4            4         PFS Family Visitation Center
# 5    5            5  Economic Self - Sufficiency Program
# 6    6            6                         Little House
# 7    7            7                        Rosener House
# 8    8            8       Meals on Wheels - South County
# 9    9            9                     Fair Oaks Branch
# 10  10           10                         Main Library
# 11  11           11                      Schaberg Branch
# 12  12           12                         Project Read
# 13  13           13                Redwood Shores Branch
# 14  14           14                       Salvation Army
# ...

# %%
pd.read_csv('.\data\sample-csv\mail_addresses.csv' ,names=["adfgfadssaf" , 'b' , 'c' , 'd' , "fdsfsa" , "fsdf" ,"fdsfs"] )
# Out:
#                                         adfgfadssaf  \
# id location_id                            attention
# 1  1             Fair Oaks Intergenerational Center
# 2  2                     PFS Second Career Services
# 3  3                     PFS Senior Peer Counseling
# 4  4                   PFS Family Visitation Center
# 5  5            Economic Self - Sufficiency Program
# 6  6                                   Little House
# 7  7                                  Rosener House
# 8  8                 Meals on Wheels - South County
# 9  9                               Fair Oaks Branch
# 10 10                                  Main Library
# 11 11                               Schaberg Branch
# 12 12                                  Project Read
# 13 13                         Redwood Shores Branch
# 14 14                                Salvation Army
# 15 15                   Adult Rehabilitation Center
# 16 16                                Salvation Army
# ...

# %%
pd.read_csv('.\data\sample-csv\mail_addresses.csv' ,names=["adfgfadssaf" , 'b' ] )
# Out:
#                                                                                                                             adfgfadssaf  \
# id location_id attention                           address_1                  address_2 city                state_province  postal_code
# 1  1           Fair Oaks Intergenerational Center  2600 Middlefield Road      NaN       Redwood City        CA                    94063
# 2  2           PFS Second Career Services          24 Second Avenue           NaN       San Mateo           CA                    94401
# 3  3           PFS Senior Peer Counseling          24 Second Avenue           NaN       San Mateo           CA                    94403
# 4  4           PFS Family Visitation Center        24 Second Avenue           NaN       San Mateo           CA                    94401
# 5  5           Economic Self - Sufficiency Program 24 Second Avenue           NaN       San Mateo           CA                    94401
# ...

# %%
pd.read_csv('.\data\sample-csv\contacts.csv')
# Out:
#     id  location_id  organization_id  service_id                     name  \
# 0    1          1.0              NaN         NaN            Susan Houston
# 1    2          1.0              NaN         NaN       Christina Gonzalez
# 2    3          2.0              NaN         NaN             Brenda Brown
# 3    4          3.0              NaN         NaN       Howard Lader, LCSW
# 4    5          4.0              NaN         NaN       Kimberly Pesavento
# 5    6          5.0              NaN         NaN                Joe Bloom
# 6    7          6.0              NaN         NaN              Peter Olson
# 7    8          6.0              NaN         NaN             Bart Charlow
# 8    9          7.0              NaN         NaN             Bart Charlow
# 9   10          7.0              NaN         NaN             Barbara Kalt
# 10  11          8.0              NaN         NaN  Marilyn Baker-Venturini
# 11  12          8.0              NaN         NaN       Graciela Hernandez
# ...

# %%
pd.read_csv('.\data\sample-csv\contacts.csv',sep='@')
# You forced the wrong separator
# Most CSV files use:

# comma ,

# tab \t

# semicolon ; pipe |
# Out:
#   File "C:\Users\nayak\AppData\Local\Temp/ipykernel_13476/3744588874.py", line 2
#     You forced the wrong separator
#         ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('.\data\sample-csv\contacts.csv',sep='|')

# %%
df
# Out:
#    id,location_id,organization_id,service_id,name,title,email,department
# 0   1,1,,,Susan Houston,Director of Older Adult Se...
# 1          2,1,,,Christina Gonzalez,Center Director,,
# 2   3,2,,,Brenda Brown,"Director, Second Career Se...
# 3   4,3,,,"Howard Lader, LCSW","Manager, Senior Pe...
# 4   5,4,,,Kimberly Pesavento,Director of Visitation,,
# 5   6,5,,,Joe Bloom,Financial Empowerment Programs...
# 6           7,6,,,Peter Olson,Little House Director,,
# 7   8,6,,,Bart Charlow,"Executive Director, Penins...
# 8   9,7,,,Bart Charlow,"Executive Director, Penins...
# 9                      10,7,,,Barbara Kalt,Director,,
# 10          11,8,,,Marilyn Baker-Venturini,Director,,
# 11      12,8,,,Graciela Hernandez,Assistant Manager,,
# 12       13,8,,,Julie Avelino,Assessment Specialist,,
# 13              14,9,,,Dave Genesy,Library Director,,
# 14    15,9,,,Maria Kramer,Library Divisions Manager,,
# 15             16,10,,,Dave Genesy,Library Director,,
# ...

# %%
pd.read_csv('.\data\sample-csv\contacts.csv',sep='|' , skiprows=[1,3])
# Out:
#    id,location_id,organization_id,service_id,name,title,email,department
# 0          2,1,,,Christina Gonzalez,Center Director,,
# 1   4,3,,,"Howard Lader, LCSW","Manager, Senior Pe...
# 2   5,4,,,Kimberly Pesavento,Director of Visitation,,
# 3   6,5,,,Joe Bloom,Financial Empowerment Programs...
# 4           7,6,,,Peter Olson,Little House Director,,
# 5   8,6,,,Bart Charlow,"Executive Director, Penins...
# 6   9,7,,,Bart Charlow,"Executive Director, Penins...
# 7                      10,7,,,Barbara Kalt,Director,,
# 8           11,8,,,Marilyn Baker-Venturini,Director,,
# 9       12,8,,,Graciela Hernandez,Assistant Manager,,
# 10       13,8,,,Julie Avelino,Assessment Specialist,,
# 11              14,9,,,Dave Genesy,Library Director,,
# 12    15,9,,,Maria Kramer,Library Divisions Manager,,
# 13             16,10,,,Dave Genesy,Library Director,,
# 14    17,10,,,Maria Kramer,Library Division Manager,,
# 15             18,11,,,Dave Genesy,Library Director,,
# ...

# %%
df1 = pd.read_csv('.\data\sample-csv\contacts.csv',sep='|' , skiprows=[1,3])

# %%
df1
# Out:
#    id,location_id,organization_id,service_id,name,title,email,department
# 0          2,1,,,Christina Gonzalez,Center Director,,
# 1   4,3,,,"Howard Lader, LCSW","Manager, Senior Pe...
# 2   5,4,,,Kimberly Pesavento,Director of Visitation,,
# 3   6,5,,,Joe Bloom,Financial Empowerment Programs...
# 4           7,6,,,Peter Olson,Little House Director,,
# 5   8,6,,,Bart Charlow,"Executive Director, Penins...
# 6   9,7,,,Bart Charlow,"Executive Director, Penins...
# 7                      10,7,,,Barbara Kalt,Director,,
# 8           11,8,,,Marilyn Baker-Venturini,Director,,
# 9       12,8,,,Graciela Hernandez,Assistant Manager,,
# 10       13,8,,,Julie Avelino,Assessment Specialist,,
# 11              14,9,,,Dave Genesy,Library Director,,
# 12    15,9,,,Maria Kramer,Library Divisions Manager,,
# 13             16,10,,,Dave Genesy,Library Director,,
# 14    17,10,,,Maria Kramer,Library Division Manager,,
# 15             18,11,,,Dave Genesy,Library Director,,
# ...

# %%
df = pd.read_csv('.\data\sample-csv\services.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# ...

# %%
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
a = df["name"]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df1 = df[["name" ,'location_id','id' ]]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is F8E2-D371
#
#  Directory of d:\SelfProject\iNeuron\Python
#
# 04-02-2026  00:54    <DIR>          .
# 04-04-2023  00:17    <DIR>          ..
# 04-02-2026  00:42    <DIR>          .git
# 04-04-2023  00:18    <DIR>          .ipynb_checkpoints
# 04-04-2023  00:17            23,057 000.python basic.ipynb
# 04-04-2023  00:17            23,471 001.python basic.ipynb
# 04-04-2023  00:17            16,952 002.whileloop.ipynb
# 04-04-2023  00:17            17,533 003.Forloop.ipynb
# 04-04-2023  00:17            39,935 004.python string and list manupulation.ipynb
# 04-04-2023  00:17            69,090 004.python string and list manupulation-nov.ipynb
# 04-04-2023  00:17            56,644 005.list manupulaton.ipynb
# 04-04-2023  00:17            54,898 006.TUPLE SET AND DICT-bckup.ipynb
# 04-04-2023  00:17            59,358 006.Tuples , set , dict .ipynb
# 04-04-2023  00:17            27,917 007.Function in pyton  (1).ipynb
# ...

# %%
pd.read_excel('.\data\sample-excel\LUSID Excel - Manage Orders.xlsx',sheet_name = "Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
# ...

# %%
df = pd.read_excel('.\data\sample-excel\LUSID Excel - Manage Orders.xlsx')

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18'],
#       dtype='object')

# %%
df = pd.ExcelFile('.\data\sample-excel\LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Executions', 'Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    pd.read_excel('.\data\sample-excel\LUSID Excel - Manage Orders.xlsx' , sheet_name=i)

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/phones.csv')
# Out:
#     id  contact_id  location_id  organization_id  service_id  country_prefix  \
# 0    1         NaN          1.0              NaN         NaN             NaN
# 1    2         NaN          1.0              NaN         NaN             NaN
# 2    3         NaN          2.0              NaN         NaN             NaN
# 3    4         NaN          2.0              NaN         NaN             NaN
# 4    5         NaN          3.0              NaN         NaN             NaN
# 5    6         NaN          3.0              NaN         NaN             NaN
# 6    7         NaN          4.0              NaN         NaN             NaN
# 7    8         NaN          4.0              NaN         NaN             NaN
# 8    9         NaN          5.0              NaN         NaN             NaN
# 9   10         NaN          5.0              NaN         NaN             NaN
# 10  11         NaN          6.0              NaN         NaN             NaN
# ...
